# %% [markdown]
# Import required libraries

# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\admin\anaconda3\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import time
from bs4 import BeautifulSoup
import re #helps to call the url

# %% [markdown]
# Amazon URL

# %%
URL = "https://www.amazon.in/s?k=laptop&crid=3H4ZV8KKLMX73&sprefix=lapto%2Caps%2C348&ref=nb_sb_noss_2"

# %% [markdown]
# Make a header to mimic a browser visit (We make headers to tell that we are not any hackers or scammers)

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) "
"Chrome/144.0.0.0 Safari/537.36"}

# %% [markdown]
# Send request to URL

# %% [markdown]
# Beautifulsoup to parse the HTML Content (It helps to convert the scarp data to html form)

# %%
data = []
print("Data list cleared")

for page in range(1, 7):  
    params = {"k": "laptop", "page": page}
    
    # Use verify=False to bypass SSL verification (for testing purposes)
    response = requests.get(URL, params=params, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")
    
    products = soup.find_all("div", {"data-component-type": "s-search-result"})

    
    
    for product in products:
        # Extract the product title
        title_tag = product.find("h2")
        if not title_tag:
            continue
        title_text = title_tag.get_text(strip=True)

        
        # Extract the product price
        price_tag = product.find("span", {"class": "a-price-whole"})
        price_text = price_tag.get_text(strip=True) if price_tag else "N/A"

        #Extract the processor
        processor = re.search(r"(i[3579]|Ryzen\s?\d)", title_text)
        processor = processor.group() if processor else None
        
        # Extract the product brand
        match = re.match(r'^\W*([A-Za-z]+)', title_text)
        brand = match.group(1).upper() if match else "UNKNOWN"

        # Extract RAM (improved version)
        ram_match = re.search(r'(\d+)\s*GB\s*(RAM|DDR\d+|LPDDR\d+)', title_text, re.IGNORECASE)
        ram = ram_match.group(1) + "GB" if ram_match else "N/A"
        
        # Extract the product rating 
        rating_tag = product.find("span", class_="a-icon-alt")
        rating = "N/A"
        if rating_tag:
            rating_match = re.search(r'(\d+\.?\d*)', rating_tag.get_text())
            rating = rating_match.group(1) if rating_match else "N/A"

        # Extract the Product SSD - Simplified
        ssd_match = re.search(r'(\d+)\s*(GB|TB)\s*(?:SSD|NVMe)', title_text, re.IGNORECASE) or re.search(r'(\d+)\s*(GB|TB)', title_text)
        ssd = (ssd_match.group(1) + ssd_match.group(2).upper()) if ssd_match else "N/A"
      

        # Extract the Product Windows Version - Improved version
        windows_version = "N/A"
        
        # Try: "Windows 11", "Windows 10", "Win11", "Win10", etc.
        windows_match = re.search(r'(?:Windows\s*|Win\s*)(\d+)', title_text, re.IGNORECASE)
        if windows_match:
            windows_version = "Windows " + windows_match.group(1)
        
        # Extract the Product Color
        color_match = re.search(r'\b(Black|Silver|Gray|Grey|White|Blue|Red|Gold|Green|Brown|Pink|Purple|Yellow|Orange|Champagne|Midnight|Space|Cosmic|Stardust|Graphite|Ash|Onyx|Platinum|Metallic)\b', title_text, re.IGNORECASE)
        color = color_match.group(1) if color_match else "N/A"

        # Extract Discount Percentage
        discount_tag = product.find("span", string=re.compile(r'%'))
        discount = discount_tag.get_text(strip=True) if discount_tag else "N/A"

        screen_match = re.search(r'(\d{1,2}\.?\d?)\s*(?=[^\d]*cm|[^\d]*["\'])',title_text,re.IGNORECASE)
        screen_size = screen_match.group(1) if screen_match else "N/A"



        # Store the extracted data in a dictionary and append to the list
        data.append({
            "Title": title_text,
            "Price": price_text,
            "Processor":processor,
            "Brand": brand,
            'RAM': ram,
            "Rating": rating,
            "Storage": ssd,
            "Windows": windows_version,
            "Color": color,
            "Discount": discount,
            "Screen Size": screen_size
        })

      
    print(f"Page {page} scraped")
    time.sleep(1)
# Out:
# Data list cleared
# Page 1 scraped
# Page 2 scraped
# Page 3 scraped
# Page 4 scraped
# Page 5 scraped
# Page 6 scraped

# %%
for product in data:
    print("Title:", product["Title"])
    print("Price:", product["Price"])
    print("Brand:", product["Brand"])
    print("Processor:",product["Processor"])
    print("RAM:", product.get("RAM"))
    print("Rating:", product.get("Rating"))
    print("Storage:", product.get("Storage"))
    print("Windows:", product.get("Windows"))
    print("Color:", product.get("Color"))
    print("Discount:",product.get("Discount"))
    print("Screen Size:",product.get("screen_size"))
    print("-" * 50)
# Out:
# Title: Dell 15, Intel Core i5 13th Gen-1334U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop
# Price: 56,990
# Brand: DELL
# Processor: i5
# RAM: 16GB
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (21% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+
# Price: 83,990
# Brand: ASUS
# Processor: None
# RAM: 16GB
# Rating: 3.8
# Storage: 1TB
# Windows: Windows 11
# Color: Gray
# Discount: (23% off)
# Screen Size: None
# --------------------------------------------------
# Title: EBook 11.6" HD Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB DDR4 | 128GB eMMC + M.2 SSD Expandable Slot | Win 11 Home |31Wh Battery | UHD Graphics 600 | Black
# Price: 10,990
# Brand: EBOOK
# Processor: None
# RAM: 4GB
# Rating: 5.0
# Storage: 4GB
# Windows: Windows 11
# Color: Black
# Discount: (56% off)
# Screen Size: None
# --------------------------------------------------
# Title: JioBook 11 with Lifetime Office | Android 4G Laptop Mediatek 8788 (JioOS) | Octa-core | 4GB RAM | 64 eMMC Storage | Thin and Light Laptop (11.6 inch, 990 Grams) | Dual Band WiFi + SIM | Blue
# Price: 10,990
# Brand: JIOBOOK
# Processor: None
# RAM: 4GB
# Rating: 2.9
# Storage: 4GB
# Windows: N/A
# Color: Blue
# Discount: (56% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fd0573TU, FHD Camera w/Shutter Laptop
# Price: 41,990
# Brand: HP
# Processor: i3
# RAM: 12GB
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (20% off)
# Screen Size: None
# --------------------------------------------------
# Title: BrowseBook 14.1" FHD IPS Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB RAM | 128GB SSD | Windows 11 | 38Wh | 1.3kg | Grey
# Price: 12,990
# Brand: BROWSEBOOK
# Processor: None
# RAM: 4GB
# Rating: 3.0
# Storage: 128GB
# Windows: Windows 11
# Color: Grey
# Discount: (57% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo {SmartChoice)Chromebook Intel Celeron N4500 (4GB RAM/64GB eMMC 5.1/11.6 Inch (29.46cm)/HD Display/2Wx2 Stereo Speakers/HD Camera/Chrome OS/Blue/1.21Kg), 82UY0014HA
# Price: 15,990
# Brand: LENOVO
# Processor: None
# RAM: 4GB
# Rating: 3.9
# Storage: 4GB
# Windows: N/A
# Color: Blue
# Discount: (56% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15 Consumer Series Laptop, Intel Core i3-1315U (13th Gen) 12GB DDR4 RAM,512GB NVMe SSD/ 15.6'' FHD Anti-Glare, Micro-Edge, Win11, M365 Basic(1yr)* Office24, Silver,1.59kg, FHD Camera with Shutter
# Price: 41,990
# Brand: HP
# Processor: i3
# RAM: 12GB
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (22% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook Go 14, AMD Ryzen 3 7320U, 8GB RAM, 512GB SSD, FHD 14", Windows 11, Office Home 2024, Mixed Black, 1.38 kg, E1404FA-NK3325WS, AMD Radeon iGPU, M365 Basic (1Year)*, Thin & Light Laptop
# Price: 34,790
# Brand: ASUS
# Processor: Ryzen 3
# RAM: 8GB
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (21% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fc0500AU, FHD Camera w/Privacy Shutter Laptop
# Price: 36,990
# Brand: HP
# Processor: Ryzen 3
# RAM: 8GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (17% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop
# Price: 69,990
# Brand: HP
# Processor: None
# RAM: 16GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: EooCoo Case Compatible for Apple MacBook Air 13.6 inch M4 A3240 M3 A3113 M2 A2681 with Touch ID,2026 2025 2024 2022,M2 M3 M4 Air 13'' Laptop Protective Plastic Hard Shell Cover Smooth, Midnight Clear
# Price: 1,139
# Brand: EOOCOO
# Processor: None
# RAM: N/A
# Rating: 4.1
# Storage: N/A
# Windows: N/A
# Color: Midnight
# Discount: (7% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook 14, Intel Core i3 13th Gen 1315U, 8GB RAM, 512GB SSD, FHD 14", Windows 11, Office Home 2024, Cool Silver, 1.40kg, X1404VA-NK761WS, Intel UHD, M365 Basic (1Year)*, Backlit Keyboard Laptop
# Price: 36,790
# Brand: ASUS
# Processor: i3
# RAM: 8GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (25% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Smartchoice Omen AMD Ryzen 7 7840Hs, 8GB RTX 4060 (16GB DDR5, 1TB SSD) FHD, 165Hz, 300Nits, IPS, 16.1''/40.9cm, Win11, Office 21, Black, 2.32kg, Xd0020ax, RGB kb, Tempest Cooling, AI Gaming Laptop
# Price: 1,26,420
# Brand: HP
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 4.0
# Storage: 1TB
# Windows: Windows 11
# Color: Black
# Discount: (9% off)
# Screen Size: None
# --------------------------------------------------
# Title: MSI Raider 18, Intel Series 2 Core Ultra 9 285HX, 46cm UHD+ 120Hz Gaming Laptop (64GB/4TB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 5090, GDDR7 24GB/Core Black/3.6Kg) A2XWJG-253IN
# Price: 4,99,990
# Brand: MSI
# Processor: None
# RAM: N/A
# Rating: 3.0
# Storage: 4TB
# Windows: Windows 11
# Color: Black
# Discount: (11% off)
# Screen Size: None
# --------------------------------------------------
# Title: New Microsoft Surface Laptop (7th Edition) - Windows 11 Home Copilot + PC - 13.8” LCD PixelSense Touchscreen - Qualcomm Snapdragon X Plus (10 Core) - 16GB RAM - 512GB SSD - Graphite - ZGM-00059
# Price: 1,29,990
# Brand: NEW
# Processor: None
# RAM: 16GB
# Rating: 5.0
# Storage: 512GB
# Windows: Windows 11
# Color: Graphite
# Discount: (4% off)
# Screen Size: None
# --------------------------------------------------
# Title: acer Aspire 3, Intel Core Celeron N4500, 12GB LPDDR4X RAM, 512GB SSD, HD, 15.6"/39.62cm, Windows 11 Home, Pure Silver, 1.5KG, A325-45, Thin and Light Laptop
# Price: 31,999
# Brand: ACER
# Processor: None
# RAM: 12GB
# Rating: 3.4
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (11% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Pavilion x360, 13th Gen Intel Core i5-1335U (16GB DDR4, 1TB SSD) FHD, 14''/35.6 cm, Touchscreen 2-in-1, Win 11, Office 21, Silver, 1.51 kg, ek1010TU/1149tu, FPR, 5MP Camera, B&O, Backlit Laptop
# Price: 77,490
# Brand: HP
# Processor: i5
# RAM: 16GB
# Rating: 3.9
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (22% off)
# Screen Size: None
# --------------------------------------------------
# Title: Thomson NEO 14.1 Inch IN-N14C Intel Celeron Dual Core N4020 Processor Windows 11 Home Notebook (8 GB RAM DDR4/ 256 GB SSD/Thin & Light Weight/Silver/Non Stop Performance Beyond 15 Hrs)
# Price: 17,990
# Brand: THOMSON
# Processor: None
# RAM: 8GB
# Rating: 4.0
# Storage: 256GB
# Windows: Windows 11
# Color: Silver
# Discount: (36% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook 15, 13th Gen, Intel Core i3-1315U, 8 GB RAM, 512GB SSD, FHD, Anti-Glare, 15.6", 39.6 cm, Windows 11 Home, M365 Basic(1yr)* Office24, Cool Silver, 1.70 kg, X1504VA-BQ321WS, Laptop
# Price: 36,990
# Brand: ASUS
# Processor: i3
# RAM: 8GB
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (27% off)
# Screen Size: None
# --------------------------------------------------
# Title: Urban Armor Gear UAG Tactical 15-inch Slim Brief, Rugged Protective Slim Secure Laptop Tablet Carrying Bag for up to 15-inch Devices - Olive
# Price: 44,499.
# Brand: URBAN
# Processor: None
# RAM: N/A
# Rating: 4.4
# Storage: N/A
# Windows: N/A
# Color: N/A
# Discount: (8% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop
# Price: 44,326
# Brand: DELL
# Processor: None
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core i5 13th Gen-1334U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop
# Price: 56,990
# Brand: DELL
# Processor: i5
# RAM: 16GB
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (21% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+
# Price: 83,990
# Brand: ASUS
# Processor: None
# RAM: 16GB
# Rating: 3.8
# Storage: 1TB
# Windows: Windows 11
# Color: Gray
# Discount: (23% off)
# Screen Size: None
# --------------------------------------------------
# Title: Thomson NEO 14.1 Inch IN-N14C Intel Celeron Dual Core N4020 Processor Windows 11 Home Notebook (8 GB RAM DDR4/ 256 GB SSD/Thin & Light Weight/Silver/Non Stop Performance Beyond 15 Hrs)
# Price: 17,990
# Brand: THOMSON
# Processor: None
# RAM: 8GB
# Rating: 4.0
# Storage: 256GB
# Windows: Windows 11
# Color: Silver
# Discount: (36% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15, Intel Core Ultra 5 125H (16GB DDR5, 1TB SSD) FHD, IPS, 15.6''/39.6cm, Win11, M365 Basic(1yr)*Office24, Silver, 1.65kg, fd1354TU, Intel Arc Graphics, FHD Camera w/Shutter, AI Powered Laptop
# Price: 69,990
# Brand: HP
# Processor: None
# RAM: 16GB
# Rating: 4.0
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (11% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 14s Intel Celeron Dual Core N4500 Laptop (8GB/512GB SSD/Win 11) 14.0" HD Display, MSO 24, Black, 1.46kg, DQ3149TU Thin and Light Business Laptop
# Price: 28,690
# Brand: HP
# Processor: None
# RAM: N/A
# Rating: 3.4
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (5% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo V15 Intel Core i3 13th Gen (16GB RAM/512GB SSD/Windows 11 Home/Office 2024/Iron Grey) 15.6" FHD (1920x1080) Antiglare 250 Nits Thin & Light Laptop/1Y Onsite/1.65 kg, 83CCA08KIN
# Price: 44,990
# Brand: LENOVO
# Processor: i3
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (38% off)
# Screen Size: None
# --------------------------------------------------
# Title: Walker Best Student & Office Work Laptop|Thin & Light|15.6" 1920 * 1080 Resolution FHD IPS Display |8GB RAM,256 GB SSD|Intel Celeron Processor N4020 | Windows 11 Home |Silver
# Price: 16,990
# Brand: WALKER
# Processor: None
# RAM: 8GB
# Rating: 2.9
# Storage: 256GB
# Windows: Windows 11
# Color: Silver
# Discount: (58% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15, 13th Gen Intel Core i7-1355U (16GB DDR4, 512GB SSD) FHD, Anti-Glare, 15.6’’/39.6cm, Win11, M365(1yr)* Office 24, Silver, 1.59kg, Iris Xe, FHD Camera w/Shutter, Backlit Laptop fd0468tu/fd0515tu
# Price: 67,990
# Brand: HP
# Processor: i7
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: acer Aspire Go 14,14th Gen, Intel Core Ultra 5 125H, 16GB DDR5, 512GB, WUXGA IPS, 14.0"/35.56cm, Win 11, MS Office, Steel Gray, 1.5 kg, AG14-71M, Backlit KB, AI Powered Laptop
# Price: 54,427
# Brand: ACER
# Processor: None
# RAM: 16GB
# Rating: 3.6
# Storage: 16GB
# Windows: Windows 11
# Color: Gray
# Discount: (25% off)
# Screen Size: None
# --------------------------------------------------
# Title: Thomson NEO 14.1 Inch IN-P14C Intel Celeron Dual Core N4020 Processor & Window 11 Notebook (8 GB RAM DDR4/ 256 GB SSD/Numeric Touch Pad/1MP Webcam/Silver)
# Price: 14,990
# Brand: THOMSON
# Processor: None
# RAM: 8GB
# Rating: 3.0
# Storage: 256GB
# Windows: N/A
# Color: Silver
# Discount: (46% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell SmartChoice G15-5530, Intel Core i5 13th Gen-13450HX, NVIDIA RTX 3050-6GB, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, 120Hz, Windows 11, MS Office 24, Dark Shadow Grey, 2.65Kg, Gaming Laptop
# Price: 77,787
# Brand: DELL
# Processor: i5
# RAM: 16GB
# Rating: 4.0
# Storage: 1TB
# Windows: Windows 11
# Color: Grey
# Discount: (26% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop
# Price: 44,326
# Brand: DELL
# Processor: None
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: Samsung Galaxy Book 4 15.6" Full HD | Intel Core i5 1335U | 16GB RAM | 512GB SSD | Win 11 Home | MS Office'2024 | Fingerprint Reader | Intel Iris XE Graphics | Backlit Keyboard |NP750XGJ-LS6IN |Silver
# Price: 55,400
# Brand: SAMSUNG
# Processor: i5
# RAM: 16GB
# Rating: 4.9
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (29% off)
# Screen Size: None
# --------------------------------------------------
# Title: Thomson NEO 14.1 Inch IN-P14C Intel Celeron Dual Core N4020 Processor & Window 11 Home Notebook (4 GB RAM DDR4/ 128 GB SSD/Numeric Touch Pad/Thin & Light Weight/Silver)
# Price: 12,990
# Brand: THOMSON
# Processor: None
# RAM: 4GB
# Rating: 3.0
# Storage: 128GB
# Windows: N/A
# Color: Silver
# Discount: (48% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Victus, 14th Gen Intel Core i5-14450HX, 6GB RTX 3050, 24GB DDR5, 512GB SSD, FHD, 144Hz, IPS, 300 nits, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.3kg, fa2303tx, RGB Gaming Laptop
# Price: 80,490
# Brand: HP
# Processor: i5
# RAM: 24GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (20% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook S16,14th Gen, Intel Core 5-210H,Metallic Design Laptop(Intel UHD iGPU/16GB RAM/512GB SSD/FHD+/16"/144Hz/Windows 11/M365 Basic(1Year)*/Office Home 2024/Silver/1.7Kg) S3607VA-RP114WS
# Price: 67,990
# Brand: ASUS
# Processor: None
# RAM: 16GB
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: Metallic
# Discount: (1% off)
# Screen Size: None
# --------------------------------------------------
# Title: MSI Thin 15, Intel 13th Gen. Core i5-13420H, 40CM FHD 144Hz Gaming Laptop(16GB/512GB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 3050,GDDR6 4GB/Cosmos Gray/1.86Kg), B13UC-1805IN
# Price: 60,625
# Brand: MSI
# Processor: i5
# RAM: N/A
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Gray
# Discount: (27% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core i5 13th Gen-1334U, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Silver, 1.62kg, [Dell 15], Backlit Keyboard, 15 Month McAfee, Thin & Light, Laptop
# Price: 57,926
# Brand: DELL
# Processor: i5
# RAM: 16GB
# Rating: 3.7
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (26% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook 15, Smartchoice, AMD Ryzen 7 5825U, 16GB RAM, 512GB SSD, FHD 15.6", Windows 11, Office Home 2024, Quiet Blue, 1.7Kg, M1502YA-BQ703WS, AMD Radeon iGPU, M365 Basic (1Year)*, 42Whr Laptop
# Price: 48,990
# Brand: ASUS
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: Blue
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Smartchoice Victus, 13th Gen Intel Core i7-13620H, 8GB RTX 5050, 24GB DDR5(Upgradeable) 1TB SSD, 144Hz, FHD, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.29kg, fa2309TX, RGB Gaming Laptop
# Price: 1,09,990
# Brand: HP
# Processor: i7
# RAM: 24GB
# Rating: 4.0
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (12% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop
# Price: 69,990
# Brand: HP
# Processor: None
# RAM: 16GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)
# Price: 22,990
# Brand: PRIMEBOOK
# Processor: None
# RAM: 8GB
# Rating: 4.3
# Storage: 8GB
# Windows: N/A
# Color: Gray
# Discount: (34% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core i5 13th Gen-1334U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop
# Price: 56,990
# Brand: DELL
# Processor: i5
# RAM: 16GB
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (21% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+
# Price: 83,990
# Brand: ASUS
# Processor: None
# RAM: 16GB
# Rating: 3.8
# Storage: 1TB
# Windows: Windows 11
# Color: Gray
# Discount: (23% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3, 12th Gen Intel Core i5-12450H (16GB LPDDR5, 512GB SSD), Anti-glare, FHD 15.6"(39.6cm), Win 11, Office Home 2024, Arctic Grey, 1.62Kg, 83ER00MDIN, Thin & Light, Backlit KB Laptop
# Price: 51,328
# Brand: LENOVO
# Processor: i5
# RAM: 16GB
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (28% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Victus, 13th Gen Intel Core i7-13620H, 8GB RTX 5060, 24GB DDR5(Upgradeable) 1TB SSD, 144Hz, 300nits, IPS, FHD, 15.6"/39.6cm, Win11, M365* Office 24, Mica Silver, 2.29Kg, fa2308TX, RGB Gaming Laptop
# Price: 1,19,490
# Brand: HP
# Processor: i7
# RAM: 24GB
# Rating: 4.2
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (12% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS TUF A15, AMD Ryzen 7 7445HS, Gaming Laptop(RTX 3050-4GB/75W TGP/32GB RAM/1TB SSD/FHD/15.6"/144Hz/Backlit Keyboard/48Whrs/Windows 11/Graphite Black/2.3 Kg) FA506NCG-HN250W
# Price: 82,990
# Brand: ASUS
# Processor: Ryzen 7
# RAM: 32GB
# Rating: 4.2
# Storage: 1TB
# Windows: Windows 11
# Color: Graphite
# Discount: (13% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook 15, Intel Core i7 13th Gen 13620H, 16GB RAM, 512GB SSD, FHD 15.6", Windows 11, Office Home 2024, Quiet Blue, 1.70kg, X1502VA-BQ838WS, Intel UHD iGPU, M365 Basic (1Year)* Laptop
# Price: 63,990
# Brand: ASUS
# Processor: i7
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Blue
# Discount: (26% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Smartchoice Victus, 13th Gen Intel Core i7-13620H, 8GB RTX 5050, 24GB DDR5(Upgradeable) 1TB SSD, 144Hz, FHD, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.29kg, fa2309TX, RGB Gaming Laptop
# Price: 1,09,990
# Brand: HP
# Processor: i7
# RAM: 24GB
# Rating: 4.0
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (12% off)
# Screen Size: None
# --------------------------------------------------
# Title: acer Nitro V 15, AMD Ryzen 7-7445HS, NVIDIA GeForce RTX 4050-6 GB, 16GB DDR5, 512GB SSD, FHD IPS, 15.6"/39.62cm, 165Hz, Win 11 Home, Obsidian Black, 2.1KG, ANV15-42, Gaming Laptop
# Price: 76,990
# Brand: ACER
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 3.8
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (29% off)
# Screen Size: None
# --------------------------------------------------
# Title: DELL 14 (2026) Intel Core 3 14th Gen 100U - (16 GB DDR5/512 GB SSD/Intel UHD Graphics/Windows 11 Home) Thin and Light Business Laptop/14.0" FHD+ IPS Display/Ice Blue/1.4 kg/MSO 2021
# Price: 46,390
# Brand: DELL
# Processor: None
# RAM: 16GB
# Rating: 5.0
# Storage: 512GB
# Windows: Windows 11
# Color: Blue
# Discount: (1% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo LOQ, AMD Ryzen 5 7235HS, RTX 3050-6GB, 24GB RAM, 512GB SSD, FHD, 15.6"/39.6cm, 144Hz, Windows 11, Office Home 2024, Grey, 2.4Kg, 3 Mon. Game Pass, 83JC00EFIN, Gaming Laptop
# Price: 76,990
# Brand: LENOVO
# Processor: Ryzen 5
# RAM: 24GB
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop
# Price: 69,990
# Brand: HP
# Processor: None
# RAM: 16GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell SmartChoice G15-5530, Intel Core i5 13th Gen-13450HX, NVIDIA RTX 3050-6GB, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, 120Hz, Windows 11, MS Office 24, Dark Shadow Grey, 2.65Kg, Gaming Laptop
# Price: 77,787
# Brand: DELL
# Processor: i5
# RAM: 16GB
# Rating: 4.0
# Storage: 1TB
# Windows: Windows 11
# Color: Grey
# Discount: (26% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Victus, AMD Ryzen 7 7445HS, 4GB RTX 2050, 16GB DDR5(Upgradable) 512GB SSD, FHD, 144Hz, 300 nits, IPS, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.29kg, fb3123AX, Backlit, Gaming Laptop
# Price: 62,990
# Brand: HP
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (15% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15, 13th Gen Intel Core i5-1335U (16GB DDR4,512GB SSD) FHD, Anti-Glare,Micro-Edge, 15.6''/39.6cm, Win11, M365(1yr)* Office24, Silver,1.59kg, fd0467tu, Iris Xe, FHD Camera w/Shutter, Backlit Laptop
# Price: 54,990
# Brand: HP
# Processor: i5
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 1TB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0015QU, Light-Weight, Next-Gen AI Laptop
# Price: 70,990
# Brand: HP
# Processor: None
# RAM: 16GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (20% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 14, Intel Core Ultra 7 155H (24GB DDR5, 1TB SSD), Micro-Edge, Anti-Glare, FHD, 14''/35.6cm, Win11, M365* Office24, Silver, 1.4kg, ep1181TU, FHD Camera, Backlit Laptop
# Price: 83,850
# Brand: HP
# Processor: None
# RAM: 24GB
# Rating: 3.0
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (5% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Omen, Intel Core Ultra 9 285H, 8GB RTX 5070, 32GB DDR5, 1TB SSD, 165Hz, 2k WUXGA, 3ms, 400 nits, 16''/40.6cm, Win11, M365* Office24, Black, 2.42kg, an0012TX, Unleashed Mode, RGB, AI Gaming Laptop
# Price: 1,77,990
# Brand: HP
# Processor: None
# RAM: 32GB
# Rating: 4.5
# Storage: 1TB
# Windows: Windows 11
# Color: Black
# Discount: (12% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo Yoga Slim 7 (Smartchoice) Intel Core Ultra 9 185H 14"(35.5cm) WUXGA-OLED Laptop (32GB RAM/1TB SSD/AI PC/Windows 11/Microsoft 365 Basic + Office Home 2024/1Yr ADP Free/Grey/1.39Kg), 83CV00B3IN
# Price: 1,09,990
# Brand: LENOVO
# Processor: None
# RAM: 32GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Grey
# Discount: (30% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo IdeaPad 5 2-in-1 AMD Ryzen AI 7 350 (24GB RAM/1TB SSD/14 (35.5cm)/WUXGA OLED/Windows 11/Lenovo AI Now/Copilot+PC/Office Home 2024/Digital Pen 2/Grey/1.5Kg), 83KT000LIN Convertible Laptop
# Price: 99,990
# Brand: LENOVO
# Processor: None
# RAM: 24GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Grey
# Discount: (25% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Smartchoice Victus, 13th Gen i7-13620H, 6GB RTX 4050, 16GB DDR4(Upgradeable) 512GB SSD, 144Hz, 300nits, FHD, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.3kg, fa2100/03/04tx, Gaming Laptop
# Price: 92,990
# Brand: HP
# Processor: i7
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (8% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop
# Price: 44,326
# Brand: DELL
# Processor: None
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: Urban Armor Gear UAG Tactical 15-inch Slim Brief, Rugged Protective Slim Secure Laptop Tablet Carrying Bag for up to 15-inch Devices - Olive
# Price: 44,499.
# Brand: URBAN
# Processor: None
# RAM: N/A
# Rating: 4.4
# Storage: N/A
# Windows: N/A
# Color: N/A
# Discount: (8% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core i5 13th Gen-1334U, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Silver, 1.62kg, [Dell 15], Backlit Keyboard, 15 Month McAfee, Thin & Light, Laptop
# Price: 57,926
# Brand: DELL
# Processor: i5
# RAM: 16GB
# Rating: 3.7
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (26% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop
# Price: 44,326
# Brand: DELL
# Processor: None
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: Microsoft New Surface Pro (11th Edition) - Windows 11 Home Copilot + PC - 13” OLED PixelSense Touchscreen - Qualcomm Snapdragon X Elite (12 Core) - 32GB RAM - 1TB SSD - Platinum - ZID-00014
# Price: 2,43,990
# Brand: MICROSOFT
# Processor: None
# RAM: 32GB
# Rating: 2.9
# Storage: 1TB
# Windows: Windows 11
# Color: Platinum
# Discount: (2% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Smartchoice Victus, 13th Gen i7-13620H, 6GB RTX 4050, 16GB DDR4(Upgradeable) 512GB SSD, 144Hz, 300nits, FHD, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.3kg, fa2100/03/04tx, Gaming Laptop
# Price: 92,990
# Brand: HP
# Processor: i7
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (8% off)
# Screen Size: None
# --------------------------------------------------
# Title: acer SmartChoice ALG, 13th Gen Intel Core i5-13420H, NVIDIA GeForce RTX 3050-6GB DDR6, 16GB RAM, 512GB SSD, FHD 15.6"/39.62 cm, 144Hz, Windows 11 Home, Steel Gray, 1.99 KG, AL15G-53,Gaming Laptop
# Price: 62,990
# Brand: ACER
# Processor: i5
# RAM: 6GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Gray
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook Go 14, AMD Ryzen 5 7520U, 8GB RAM, 512GB SSD, FHD 14"(1920 x 1080), Windows 11, Office Home 2024, M365 Basic (1Year)*, Black, 1.38kg, E1404FA-EB2522WS, AMD Radeon iGPU Laptop
# Price: 37,577
# Brand: ASUS
# Processor: Ryzen 5
# RAM: 8GB
# Rating: 5.0
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (23% off)
# Screen Size: None
# --------------------------------------------------
# Title: Acer Aspire Lite, AMD Ryzen 7-7730U, 16 GB RAM, 512 GB SSD, Full HD IPS,15.6"/39.62 cm, Windows 11 Home, MS Office, Steel Gray, 1.59 KG, AL15-41, Thin and Light Laptop
# Price: 46,990
# Brand: ACER
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Gray
# Discount: (30% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo LOQ 2024, Intel Core i5-13450HX, 13th Gen, NVIDIA RTX 4050-6GB, 16GB RAM, 512GB SSD, FHD 144Hz, 15.6"/39.6cm, Windows 11, Office Home 2024, Grey, 2.4Kg, 83DV018JIN, 1Yr ADP Free Gaming Laptop
# Price: 89,990
# Brand: LENOVO
# Processor: i5
# RAM: 16GB
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (22% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS TUF A16 (2025), AMD Ryzen 7 7445HS, Gaming Laptop (RTX 4050-6GB/140W TGP/16GB RAM/1TB SSD/FHD+/16"/144Hz/56Whrs/Windows 11/M365 Basic (1Year)*/Office Home 2024/Mecha Gray/2.2Kg) FA607NUG-RL189WS
# Price: 89,990
# Brand: ASUS
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 4.2
# Storage: 1TB
# Windows: Windows 11
# Color: Gray
# Discount: (22% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 1 AMD Ryzen 5 5500U 15.6" HD Thin and Light Laptop (8GB/512GB SSD/Windows 11 Home/Office Home 2024/1 Year ADP Free/Grey/1.6Kg), 82R4011MIN
# Price: 38,490
# Brand: LENOVO
# Processor: Ryzen 5
# RAM: N/A
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (30% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+
# Price: 83,990
# Brand: ASUS
# Processor: None
# RAM: 16GB
# Rating: 3.8
# Storage: 1TB
# Windows: Windows 11
# Color: Gray
# Discount: (23% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop
# Price: 69,990
# Brand: HP
# Processor: None
# RAM: 16GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo V15 AMD Ryzen 7 7730U 15.6" (39.62cm) FHD 250 Nits Antiglare Thin and Light Laptop (Free MS Office) Lifetime (16GB/512GB SSD/Windows 11/Iron Grey/1.65 Kg) 1 Year Brand Warranty, 83CRA01SIN
# Price: 52,999
# Brand: LENOVO
# Processor: Ryzen 7
# RAM: N/A
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (35% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Gaming V16 (2025) 14th Gen,Intel Core 7 240H Gaming Laptop (RTX 4050-6GB/16GB RAM/512GB SSD/Windows 11 Home/16/144Hz/M365*/Office Home 2024, Matte Black,1.95 Kg),V3607VU-RP275WS
# Price: 92,990
# Brand: ASUS
# Processor: None
# RAM: 16GB
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (18% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Professional 14 (2025), Intel Core i3 13th Gen 1315U - (16 GB/512 GB SSD/Intel UHD Graphics/Windows 11 Pro) Thin and Light Business Laptop/14.0" HD Display/Turbo Silver/1.4 Kg/MSO 2021
# Price: 44,800
# Brand: HP
# Processor: i3
# RAM: N/A
# Rating: 5.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (9% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo V14 Intel Core i5 13th Gen 14" FHD (1920x1080) Antiglare 250 Nits Thin and Light Laptop (16GB RAM/512GB SSD/Windows 11 Home/Office 2024/Iron Grey/1.43 kg), 83A0A0PTIN
# Price: 53,500
# Brand: LENOVO
# Processor: i5
# RAM: 16GB
# Rating: 3.8
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (29% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook Go 15, 7000 Series, AMD Ryzen 3 7320U, 8 GB RAM, 512GB SSD, FHD, Anti-Glare, 15.6", 39.6 cm, Windows 11 Home, M365 Basic(1yr)* Office24, Cool Silver, 1.63 kg, E1504FA-BQ2321WS, Laptop
# Price: 34,990
# Brand: ASUS
# Processor: Ryzen 3
# RAM: 8GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (20% off)
# Screen Size: None
# --------------------------------------------------
# Title: Google Pixelbook Go 128GB Multi-Touch Chromebook/Laptop (Just Black)
# Price: 49,990
# Brand: GOOGLE
# Processor: None
# RAM: N/A
# Rating: 4.4
# Storage: 128GB
# Windows: N/A
# Color: Black
# Discount: (47% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo ThinkBook 16, AMD Ryzen 7 7735HS, 16GB RAM, 512GB SSD, WUXGA IPS 16", Windows 11 Home, Office 2024, 1.7kg, 21MWA0R4IN, Backlit Keyboard, Fingerprint, 300 Nits, 1Y Warranty, Aluminium Top Laptop
# Price: 59,990
# Brand: LENOVO
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: N/A
# Discount: (35% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook Go 14, AMD Ryzen 5 7520U, 16GB RAM,512GB SSD,FHD,14,60Hz,42WHrs,Windows 11,M365 Basic (1Year)*,Office Home 2024,Mixed Black,Backlit KB,1.38 kg E1404FA-NK5542WS, Thin & Light Laptop
# Price: 42,990
# Brand: ASUS
# Processor: Ryzen 5
# RAM: 16GB
# Rating: 4.5
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell G15-5530, Intel Core i5 13th Gen -13450HX, RTX 3050-6GB, 16GB DDR5, 512GB SSD, FHD, 15.6"/39.62cm, 120Hz, Windows 11, MS Office 21, Dark Shadow Grey, 2.65KG, G15-5530, Backlit KB, Gaming Laptop
# Price: 75,990
# Brand: DELL
# Processor: i5
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (23% off)
# Screen Size: None
# --------------------------------------------------
# Title: acer Aspire Lite, Intel Core 5 210H Processor, 16 GB RAM, 512 GB SSD, Full HD IPS, 15.6"/39.62 cm, Windows 11 Home, MSO, Pure Silver, 1.70 kgs, AL15-52H, Backlit Keyboard, Thin and Light Laptop
# Price: 54,999
# Brand: ACER
# Processor: None
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (31% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core i5 13th Gen-1334U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop
# Price: 56,990
# Brand: DELL
# Processor: i5
# RAM: 16GB
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (21% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+
# Price: 83,990
# Brand: ASUS
# Processor: None
# RAM: 16GB
# Rating: 3.8
# Storage: 1TB
# Windows: Windows 11
# Color: Gray
# Discount: (23% off)
# Screen Size: None
# --------------------------------------------------
# Title: Thomson NEO 14.1 Inch IN-P14C Intel Dual Core 4020 & Window 11 Notebook (8 GB RAM DDR4/ 256 GB SSD/Numeric Touch Pad/1MP Webcam/White)
# Price: 14,990
# Brand: THOMSON
# Processor: None
# RAM: 8GB
# Rating: N/A
# Storage: 256GB
# Windows: N/A
# Color: White
# Discount: (46% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook Go 15, 7000 Series, AMD Ryzen 3 7320U, 8 GB RAM, 512GB SSD, FHD, Anti-Glare, 15.6", 39.6 cm, Windows 11 Home, M365 Basic(1yr)* Office24, Cool Silver, 1.63 kg, E1504FA-BQ2321WS, Laptop
# Price: 34,990
# Brand: ASUS
# Processor: Ryzen 3
# RAM: 8GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (20% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook Go 14, AMD Ryzen 5 7520U, 16GB RAM,512GB SSD,FHD,14,60Hz,42WHrs,Windows 11,M365 Basic (1Year)*,Office Home 2024,Mixed Black,Backlit KB,1.38 kg E1404FA-NK5542WS, Thin & Light Laptop
# Price: 42,990
# Brand: ASUS
# Processor: Ryzen 5
# RAM: 16GB
# Rating: 4.5
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15 Laptop, AMD Ryzen 7 5825U [16GB DDR4,512GB SSD] [Win11, Office Home'2024/M365 Basic(1yr)*] [Anti-Glare,Micro-Edge,15.6''/39.6cm FHD]Silver,1.59kg [Backlit KB+FHD Camera+Radeon Graphics] fc0533AU
# Price: 49,990
# Brand: HP
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (17% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, AMD Ryzen 7-7730U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.6cm, Windows 11, MSO-24, Platinum Silver, 1.63Kg, [Dell 15], 120Hz 250nits, AMD Radeon Graphics, Standard Keyboard, Thin & Light, Laptop
# Price: 51,990
# Brand: DELL
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 3.6
# Storage: 512GB
# Windows: Windows 11
# Color: Platinum
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: Microsoft Surface Laptop Studio - 14.4 Inches Touchscreen - Intel Core I5-16Gb Memory - 256Gb Ssd - Platinum Windows 11 (Thr-00022) - Wi-Fi
# Price: 1,24,990
# Brand: MICROSOFT
# Processor: None
# RAM: N/A
# Rating: 3.1
# Storage: 256GB
# Windows: Windows 11
# Color: Platinum
# Discount: (34% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell SmartChoice G15-5530, Intel Core i5 13th Gen-13450HX, NVIDIA RTX 3050-6GB, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, 120Hz, Windows 11, MS Office 24, Dark Shadow Grey, 2.65Kg, Gaming Laptop
# Price: 77,787
# Brand: DELL
# Processor: i5
# RAM: 16GB
# Rating: 4.0
# Storage: 1TB
# Windows: Windows 11
# Color: Grey
# Discount: (26% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Laptop 15, Intel Core i5-1335U-13th Gen, (16GB DDR4,512GB SSD) Anti-Glare, Micro-Edge, FHD, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, Iris Xe, FHD Camera w/Shutter
# Price: 55,990
# Brand: HP
# Processor: i5
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (22% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop
# Price: 69,990
# Brand: HP
# Processor: None
# RAM: 16GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop
# Price: 44,326
# Brand: DELL
# Processor: None
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook 15 (2025), 13th Gen,Intel Core i3-1315U, 8GB RAM, 512GB SSD, FHD, 15.6", 39.6 cm, Windows 11 Home,M365 Basic(1 Year)* Office 2024,Cool Silver,1.7 Kg, X1504VA-D5321WS, Thin & Light Laptop
# Price: 37,877
# Brand: ASUS
# Processor: i3
# RAM: 8GB
# Rating: 5.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (26% off)
# Screen Size: None
# --------------------------------------------------
# Title: Thomson 15.6 Inch In-N15I Windows 11, Intel Corei3 12Th Gen 1215U (8GB DDR / 512GB SSD/Backlight Keyboard) Window 11 (Stylish, 1.65Kg, Ultra Performance/Grey Brush) Notebook
# Price: 26,490
# Brand: THOMSON
# Processor: i3
# RAM: N/A
# Rating: 2.5
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (41% off)
# Screen Size: None
# --------------------------------------------------
# Title: acer Professional 14[New Launch], 13th Gen Intel Core i7-1355U Turbo Boost, 32GB DDR4, 1TB SSD, Win11 Pro, MSO21, 14inch FHD Laptop, 3 Year Warranty, 1 Year Anti Virus, Fingerprint, Backlit KB
# Price: 83,690
# Brand: ACER
# Processor: i7
# RAM: 32GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: N/A
# Discount: (7% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook 15, Smartchoice,Intel Corei5 13thGen 13420H, 16GB RAM, 512GB SSD, FHD 15.6", Win11, Office Home'24, M365 Basic (1Year)*, Cool Silver, 1.70kg, X1502VA-BQ835WS, Intel UHD iGPU, Laptop
# Price: 58,990
# Brand: ASUS
# Processor: i5
# RAM: 16GB
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo V15 G4 AMD Athlon Silver 7120U Laptop 8GB LPDDR5 Ram, 512 GB SSD PCIe, Windows 11/MS Office,15.6" FHD Screen, AMD Radeon 610M, Silver, 1 Year Brand Warranty
# Price: 32,999
# Brand: LENOVO
# Processor: None
# RAM: 8GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (58% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Ultra 7 255H / 32 GB DDR5 RAM/ 1 TB SSD/Windows 11 Pro/5 MP IR AI Camera/ 14.0 inch AG WUXGA/Intel® Wi-Fi 7 BE201 (2x2) and Bluetooth 5.4 /Fingerprint Reader (C1KK0PT)
# Price: 1,66,400
# Brand: HP
# Processor: None
# RAM: 32GB
# Rating: N/A
# Storage: 1TB
# Windows: Windows 11
# Color: N/A
# Discount: (32% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15 Laptop, AMD Ryzen 5 7520U (16GB DDR5,512GB SSD) Win11,M365 Basic(1yr)*Office Home24, Anti-Glare,15.6''/39.6cm,FHD,Backlit KB,FHD Camera w/Privacy Shutter,Radeon Graphics, Silver,1.59kg FC0690AU
# Price: 45,990
# Brand: HP
# Processor: Ryzen 5
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (17% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo 14 (2025), Intel Core i5 13th Gen 13420H - (16 GB/512 GB SSD/Intel UHD Graphics/Windows 11 Pro) Thin and Light Business Laptop/14.0" FHD Display/Iron Grey/1.4 kg/Microsoft Office 2021
# Price: 54,300
# Brand: LENOVO
# Processor: i5
# RAM: N/A
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (22% off)
# Screen Size: None
# --------------------------------------------------
# Title: Urban Armor Gear UAG Tactical 15-inch Slim Brief, Rugged Protective Slim Secure Laptop Tablet Carrying Bag for up to 15-inch Devices - Olive
# Price: 44,499.
# Brand: URBAN
# Processor: None
# RAM: N/A
# Rating: 4.4
# Storage: N/A
# Windows: N/A
# Color: N/A
# Discount: (8% off)
# Screen Size: None
# --------------------------------------------------
# Title: acer Aspire Lite, Intel Core 5 210H Processor, 16 GB RAM, 512 GB SSD, Full HD IPS, 15.6"/39.62 cm, Windows 11 Home, MSO, Pure Silver, 1.70 kgs, AL15-52H, Backlit Keyboard, Thin and Light Laptop
# Price: 54,999
# Brand: ACER
# Processor: None
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (31% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core i5 13th Gen-1334U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop
# Price: 56,990
# Brand: DELL
# Processor: i5
# RAM: 16GB
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (21% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+
# Price: 83,990
# Brand: ASUS
# Processor: None
# RAM: 16GB
# Rating: 3.8
# Storage: 1TB
# Windows: Windows 11
# Color: Gray
# Discount: (23% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo 14 (2025), Intel Core i5 13th Gen 13420H - (16 GB/512 GB SSD/Intel UHD Graphics/Windows 11 Pro) Thin and Light Business Laptop/14.0" FHD Display/Iron Grey/1.4 kg/Microsoft Office 2021
# Price: 54,300
# Brand: LENOVO
# Processor: i5
# RAM: N/A
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (22% off)
# Screen Size: None
# --------------------------------------------------
# Title: acer Professional 14[New Launch], 13th Gen Intel Core i7-1355U Turbo Boost, 32GB DDR4, 1TB SSD, Win11 Pro, MSO21, 14inch FHD Laptop, 3 Year Warranty, 1 Year Anti Virus, Fingerprint, Backlit KB
# Price: 83,690
# Brand: ACER
# Processor: i7
# RAM: 32GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: N/A
# Discount: (7% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop
# Price: 44,326
# Brand: DELL
# Processor: None
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: acer Aspire Lite 12th Gen Intel Core i3-1215U Premium Metal Laptop (Windows 11 Home/16 GB RAM/512GB SSD) AL15-52, 39.62cm (15.6") Full HD Display, Metal Body, Steel Gray, 1.59 Kg
# Price: 37,990
# Brand: ACER
# Processor: i3
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Gray
# Discount: (28% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15, AMD Ryzen 7 5825U (16GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge,15.6''/39.6cm, Win11, M365(1yr)* Office24, Silver, 1.59kg, fc0476AU, Radeon Graphics, FHD Camera w/Shutter, Backlit Laptop
# Price: 49,990
# Brand: HP
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (10% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3 12th Gen Intel Core i5-12450H 15.6 Inch (39.6cm) FHD Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office Home 2024/3months Game Pass/Arctic Grey/1.62Kg), 83ER00MCIN
# Price: 50,900
# Brand: LENOVO
# Processor: i5
# RAM: N/A
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (34% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15 255R G10, AMD Ryzen 5 7535U Hexa Core (6 Core, 12 Threads, 2.9 to Max 4.3 Ghz) (8 GB/512 GB SSD/AMD Radeon Graphics/Windows 11) Thin and Light Laptop(15.6 inch HD Display, Matt Silver, 1.45 kg
# Price: 38,990
# Brand: HP
# Processor: Ryzen 5
# RAM: N/A
# Rating: 4.5
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (13% off)
# Screen Size: None
# --------------------------------------------------
# Title: Microsoft New Surface Pro 12" - Windows 11 Home Copilot+ PC - LCD PixelSense Touchscreen - Qualcomm Snapdragon X Plus (8 Core) - 16GB RAM - 256GB SSD - Platinum - EP2-27654
# Price: 82,526
# Brand: MICROSOFT
# Processor: None
# RAM: 16GB
# Rating: 3.3
# Storage: 256GB
# Windows: Windows 11
# Color: Platinum
# Discount: (12% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop
# Price: 69,990
# Brand: HP
# Processor: None
# RAM: 16GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop
# Price: 44,326
# Brand: DELL
# Processor: None
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: Microsoft Surface Laptop 5 | Laptop5-13.5� Inches- Touch Screen - Intel Core i5 12th Gen. (8GB RAM, 256GB SSD) - Windows 11 - Platinum
# Price: 93,990
# Brand: MICROSOFT
# Processor: i5
# RAM: 8GB
# Rating: 4.2
# Storage: 256GB
# Windows: Windows 11
# Color: Platinum
# Discount: (20% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo Smartchoice Ideapad Slim 3, 13th Gen Intel Core i7 13620H, 16GB RAM, 512GB SSD, WUXGA IPS, 15.3"/38.8cm, Win 11, Office 2024, Top Metal Cover Grey, 1.6Kg, 83K100CJIN/S1IN, Backlit KB, Laptop
# Price: 75,990
# Brand: LENOVO
# Processor: i7
# RAM: 16GB
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (15% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo ThinkBook 16 AMD Ryzen 5 7535HS (8GB RAM/512GB SSD/Win 11 Home/Office 2024/Backlit Keyboard/Fingerprint) 16" WUXGA IPS 300 Nits Thin & Light Laptop/1Y Warranty/Aluminium Top/1.7kg, 21MWA0BRIN
# Price: 48,500
# Brand: LENOVO
# Processor: Ryzen 5
# RAM: 8GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: N/A
# Discount: (93% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 1, AMD Ryzen 5 5500U, 16GB RAM, 512GB SSD, HD, 15.6", Windows 11 Home, MS Office 21, Cloud Grey, 1.61Kg, 82R400ERIN, Integrated AMD Graphics, 1Yr ADP Free, Thin and Light Laptop
# Price: 42,000
# Brand: LENOVO
# Processor: Ryzen 5
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (11% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3, 13th Gen Intel Core i5 13420H, 24GB RAM, 1TB SSD, WUXGA IPS, 15.3"/38.8cm, Windows 11, Office Home 2024, Grey, 1.6Kg, Backlit Keyboard, 1Yr ADP Free, 83K100PLIN, Laptop
# Price: 69,990
# Brand: LENOVO
# Processor: i5
# RAM: 24GB
# Rating: 4.4
# Storage: 1TB
# Windows: Windows 11
# Color: Grey
# Discount: (20% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo IdeaPad Flex 5 AMD Ryzen 5 5625U (16GB RAM/512GB SSD/14 (35.5cm)/WUXGA IPS/Windows 11/Office Home 2024/Lenovo Digital Pen/1Yr ADP/Grey/1.5Kg), 82XX00G4IN Convertible Laptop
# Price: N/A
# Brand: LENOVO
# Processor: Ryzen 5
# RAM: 16GB
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: N/A
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo ThinkBook 16, AMD Ryzen 7 7735HS, 16GB RAM, 512GB SSD, WUXGA IPS 16", Windows 11 Home, 1.7kg, 21MWA0AUIN, Backlit Keyboard, Fingerprint, 300 Nits, 1Y Warranty, Aluminium Top Laptop
# Price: 57,990
# Brand: LENOVO
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: N/A
# Discount: (38% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook 15,13th Gen,Intel Core i7-13620H(Intel UHD iGPU/16GB RAM/1TB SSD/FHD/15.6"/60Hz/Backlit Keyboard/42Whr/Windows 11/M365 Basic (1Year)*/Office Home 2024/Quiet Blue/1.7 Kg)X1502VA-BQ1298WS
# Price: 67,990
# Brand: ASUS
# Processor: i7
# RAM: 16GB
# Rating: 4.0
# Storage: 1TB
# Windows: Windows 11
# Color: Blue
# Discount: (23% off)
# Screen Size: None
# --------------------------------------------------
# Title: Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)
# Price: 22,990
# Brand: PRIMEBOOK
# Processor: None
# RAM: 8GB
# Rating: 4.3
# Storage: 8GB
# Windows: N/A
# Color: Gray
# Discount: (34% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 14, AMD Ryzen AI R5-340, 16GB LPDDR5X, 512GB SSD, FHD+, 14"/35.56cm, Win11, MSO 2024, Ice Blue, 1.52 Kg, [Dell 14], 300 Nits IPS, AMD Radeon Graphics, Backlit+FPS Keyboard, AI Powered Laptop
# Price: 73,490
# Brand: DELL
# Processor: None
# RAM: 16GB
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Blue
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------

# %%
data
# Out:
# [{'Title': 'Dell 15, Intel Core i5 13th Gen-1334U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop',
#   'Price': '56,990',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.7',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(21% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+',
#   'Price': '83,990',
#   'Processor': None,
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '3.8',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(23% off)',
#   'Screen Size': '14'},
#  {'Title': 'EBook 11.6" HD Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB DDR4 | 128GB eMMC + M.2 SSD Expandable Slot | Win 11 Home |31Wh Battery | UHD Graphics 600 | Black',
#   'Price': '10,990',
#   'Processor': None,
#   'Brand': 'EBOOK',
#   'RAM': '4GB',
#   'Rating': '5.0',
#   'Storage': '4GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(56% off)',
#   'Screen Size': '11.6'},
#  {'Title': 'JioBook 11 with Lifetime Office | Android 4G Laptop Mediatek 8788 (JioOS) | Octa-core | 4GB RAM | 64 eMMC Storage | Thin and Light Laptop (11.6 inch, 990 Grams) | Dual Band WiFi + SIM | Blue',
#   'Price': '10,990',
#   'Processor': None,
#   'Brand': 'JIOBOOK',
#   'RAM': '4GB',
#   'Rating': '2.9',
#   'Storage': '4GB',
#   'Windows': 'N/A',
#   'Color': 'Blue',
#   'Discount': '(56% off)',
#   'Screen Size': 'N/A'},
#  {'Title': "HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fd0573TU, FHD Camera w/Shutter Laptop",
#   'Price': '41,990',
#   'Processor': 'i3',
#   'Brand': 'HP',
#   'RAM': '12GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'BrowseBook 14.1" FHD IPS Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB RAM | 128GB SSD | Windows 11 | 38Wh | 1.3kg | Grey',
#   'Price': '12,990',
#   'Processor': None,
#   'Brand': 'BROWSEBOOK',
#   'RAM': '4GB',
#   'Rating': '3.0',
#   'Storage': '128GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(57% off)',
#   'Screen Size': '14.1'},
#  {'Title': 'Lenovo {SmartChoice)Chromebook Intel Celeron N4500 (4GB RAM/64GB eMMC 5.1/11.6 Inch (29.46cm)/HD Display/2Wx2 Stereo Speakers/HD Camera/Chrome OS/Blue/1.21Kg), 82UY0014HA',
#   'Price': '15,990',
#   'Processor': None,
#   'Brand': 'LENOVO',
#   'RAM': '4GB',
#   'Rating': '3.9',
#   'Storage': '4GB',
#   'Windows': 'N/A',
#   'Color': 'Blue',
#   'Discount': '(56% off)',
#   'Screen Size': '46'},
#  {'Title': "HP 15 Consumer Series Laptop, Intel Core i3-1315U (13th Gen) 12GB DDR4 RAM,512GB NVMe SSD/ 15.6'' FHD Anti-Glare, Micro-Edge, Win11, M365 Basic(1yr)* Office24, Silver,1.59kg, FHD Camera with Shutter",
#   'Price': '41,990',
#   'Processor': 'i3',
#   'Brand': 'HP',
#   'RAM': '12GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(22% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook Go 14, AMD Ryzen 3 7320U, 8GB RAM, 512GB SSD, FHD 14", Windows 11, Office Home 2024, Mixed Black, 1.38 kg, E1404FA-NK3325WS, AMD Radeon iGPU, M365 Basic (1Year)*, Thin & Light Laptop',
#   'Price': '34,790',
#   'Processor': 'Ryzen 3',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(21% off)',
#   'Screen Size': '14'},
#  {'Title': "HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fc0500AU, FHD Camera w/Privacy Shutter Laptop",
#   'Price': '36,990',
#   'Processor': 'Ryzen 3',
#   'Brand': 'HP',
#   'RAM': '8GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(17% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop",
#   'Price': '69,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '16'},
#  {'Title': "EooCoo Case Compatible for Apple MacBook Air 13.6 inch M4 A3240 M3 A3113 M2 A2681 with Touch ID,2026 2025 2024 2022,M2 M3 M4 Air 13'' Laptop Protective Plastic Hard Shell Cover Smooth, Midnight Clear",
#   'Price': '1,139',
#   'Processor': None,
#   'Brand': 'EOOCOO',
#   'RAM': 'N/A',
#   'Rating': '4.1',
#   'Storage': 'N/A',
#   'Windows': 'N/A',
#   'Color': 'Midnight',
#   'Discount': '(7% off)',
#   'Screen Size': '13'},
#  {'Title': 'ASUS Vivobook 14, Intel Core i3 13th Gen 1315U, 8GB RAM, 512GB SSD, FHD 14", Windows 11, Office Home 2024, Cool Silver, 1.40kg, X1404VA-NK761WS, Intel UHD, M365 Basic (1Year)*, Backlit Keyboard Laptop',
#   'Price': '36,790',
#   'Processor': 'i3',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(25% off)',
#   'Screen Size': '14'},
#  {'Title': "HP Smartchoice Omen AMD Ryzen 7 7840Hs, 8GB RTX 4060 (16GB DDR5, 1TB SSD) FHD, 165Hz, 300Nits, IPS, 16.1''/40.9cm, Win11, Office 21, Black, 2.32kg, Xd0020ax, RGB kb, Tempest Cooling, AI Gaming Laptop",
#   'Price': '1,26,420',
#   'Processor': 'Ryzen 7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(9% off)',
#   'Screen Size': '16.1'},
#  {'Title': 'MSI Raider 18, Intel Series 2 Core Ultra 9 285HX, 46cm UHD+ 120Hz Gaming Laptop (64GB/4TB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 5090, GDDR7 24GB/Core Black/3.6Kg) A2XWJG-253IN',
#   'Price': '4,99,990',
#   'Processor': None,
#   'Brand': 'MSI',
#   'RAM': 'N/A',
#   'Rating': '3.0',
#   'Storage': '4TB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(11% off)',
#   'Screen Size': '46'},
#  {'Title': 'New Microsoft Surface Laptop (7th Edition) - Windows 11 Home Copilot + PC - 13.8” LCD PixelSense Touchscreen - Qualcomm Snapdragon X Plus (10 Core) - 16GB RAM - 512GB SSD - Graphite - ZGM-00059',
#   'Price': '1,29,990',
#   'Processor': None,
#   'Brand': 'NEW',
#   'RAM': '16GB',
#   'Rating': '5.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Graphite',
#   'Discount': '(4% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'acer Aspire 3, Intel Core Celeron N4500, 12GB LPDDR4X RAM, 512GB SSD, HD, 15.6"/39.62cm, Windows 11 Home, Pure Silver, 1.5KG, A325-45, Thin and Light Laptop',
#   'Price': '31,999',
#   'Processor': None,
#   'Brand': 'ACER',
#   'RAM': '12GB',
#   'Rating': '3.4',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(11% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP Pavilion x360, 13th Gen Intel Core i5-1335U (16GB DDR4, 1TB SSD) FHD, 14''/35.6 cm, Touchscreen 2-in-1, Win 11, Office 21, Silver, 1.51 kg, ek1010TU/1149tu, FPR, 5MP Camera, B&O, Backlit Laptop",
#   'Price': '77,490',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(22% off)',
#   'Screen Size': '14'},
#  {'Title': 'Thomson NEO 14.1 Inch IN-N14C Intel Celeron Dual Core N4020 Processor Windows 11 Home Notebook (8 GB RAM DDR4/ 256 GB SSD/Thin & Light Weight/Silver/Non Stop Performance Beyond 15 Hrs)',
#   'Price': '17,990',
#   'Processor': None,
#   'Brand': 'THOMSON',
#   'RAM': '8GB',
#   'Rating': '4.0',
#   'Storage': '256GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(36% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'ASUS Vivobook 15, 13th Gen, Intel Core i3-1315U, 8 GB RAM, 512GB SSD, FHD, Anti-Glare, 15.6", 39.6 cm, Windows 11 Home, M365 Basic(1yr)* Office24, Cool Silver, 1.70 kg, X1504VA-BQ321WS, Laptop',
#   'Price': '36,990',
#   'Processor': 'i3',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(27% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Urban Armor Gear UAG Tactical 15-inch Slim Brief, Rugged Protective Slim Secure Laptop Tablet Carrying Bag for up to 15-inch Devices - Olive',
#   'Price': '44,499.',
#   'Processor': None,
#   'Brand': 'URBAN',
#   'RAM': 'N/A',
#   'Rating': '4.4',
#   'Storage': 'N/A',
#   'Windows': 'N/A',
#   'Color': 'N/A',
#   'Discount': '(8% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop',
#   'Price': '44,326',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Dell 15, Intel Core i5 13th Gen-1334U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop',
#   'Price': '56,990',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.7',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(21% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+',
#   'Price': '83,990',
#   'Processor': None,
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '3.8',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(23% off)',
#   'Screen Size': '14'},
#  {'Title': 'Thomson NEO 14.1 Inch IN-N14C Intel Celeron Dual Core N4020 Processor Windows 11 Home Notebook (8 GB RAM DDR4/ 256 GB SSD/Thin & Light Weight/Silver/Non Stop Performance Beyond 15 Hrs)',
#   'Price': '17,990',
#   'Processor': None,
#   'Brand': 'THOMSON',
#   'RAM': '8GB',
#   'Rating': '4.0',
#   'Storage': '256GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(36% off)',
#   'Screen Size': 'N/A'},
#  {'Title': "HP 15, Intel Core Ultra 5 125H (16GB DDR5, 1TB SSD) FHD, IPS, 15.6''/39.6cm, Win11, M365 Basic(1yr)*Office24, Silver, 1.65kg, fd1354TU, Intel Arc Graphics, FHD Camera w/Shutter, AI Powered Laptop",
#   'Price': '69,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(11% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'HP 14s Intel Celeron Dual Core N4500 Laptop (8GB/512GB SSD/Win 11) 14.0" HD Display, MSO 24, Black, 1.46kg, DQ3149TU Thin and Light Business Laptop',
#   'Price': '28,690',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': 'N/A',
#   'Rating': '3.4',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(5% off)',
#   'Screen Size': '14.0'},
#  {'Title': 'Lenovo V15 Intel Core i3 13th Gen (16GB RAM/512GB SSD/Windows 11 Home/Office 2024/Iron Grey) 15.6" FHD (1920x1080) Antiglare 250 Nits Thin & Light Laptop/1Y Onsite/1.65 kg, 83CCA08KIN',
#   'Price': '44,990',
#   'Processor': 'i3',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(38% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Walker Best Student & Office Work Laptop|Thin & Light|15.6" 1920 * 1080 Resolution FHD IPS Display |8GB RAM,256 GB SSD|Intel Celeron Processor N4020 | Windows 11 Home |Silver',
#   'Price': '16,990',
#   'Processor': None,
#   'Brand': 'WALKER',
#   'RAM': '8GB',
#   'Rating': '2.9',
#   'Storage': '256GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(58% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'HP 15, 13th Gen Intel Core i7-1355U (16GB DDR4, 512GB SSD) FHD, Anti-Glare, 15.6’’/39.6cm, Win11, M365(1yr)* Office 24, Silver, 1.59kg, Iris Xe, FHD Camera w/Shutter, Backlit Laptop fd0468tu/fd0515tu',
#   'Price': '67,990',
#   'Processor': 'i7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(16% off)',
#   'Screen Size': '39.6'},
#  {'Title': 'acer Aspire Go 14,14th Gen, Intel Core Ultra 5 125H, 16GB DDR5, 512GB, WUXGA IPS, 14.0"/35.56cm, Win 11, MS Office, Steel Gray, 1.5 kg, AG14-71M, Backlit KB, AI Powered Laptop',
#   'Price': '54,427',
#   'Processor': None,
#   'Brand': 'ACER',
#   'RAM': '16GB',
#   'Rating': '3.6',
#   'Storage': '16GB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(25% off)',
#   'Screen Size': '14.0'},
#  {'Title': 'Thomson NEO 14.1 Inch IN-P14C Intel Celeron Dual Core N4020 Processor & Window 11 Notebook (8 GB RAM DDR4/ 256 GB SSD/Numeric Touch Pad/1MP Webcam/Silver)',
#   'Price': '14,990',
#   'Processor': None,
#   'Brand': 'THOMSON',
#   'RAM': '8GB',
#   'Rating': '3.0',
#   'Storage': '256GB',
#   'Windows': 'N/A',
#   'Color': 'Silver',
#   'Discount': '(46% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Dell SmartChoice G15-5530, Intel Core i5 13th Gen-13450HX, NVIDIA RTX 3050-6GB, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, 120Hz, Windows 11, MS Office 24, Dark Shadow Grey, 2.65Kg, Gaming Laptop',
#   'Price': '77,787',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(26% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop',
#   'Price': '44,326',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Samsung Galaxy Book 4 15.6" Full HD | Intel Core i5 1335U | 16GB RAM | 512GB SSD | Win 11 Home | MS Office\'2024 | Fingerprint Reader | Intel Iris XE Graphics | Backlit Keyboard |NP750XGJ-LS6IN |Silver',
#   'Price': '55,400',
#   'Processor': 'i5',
#   'Brand': 'SAMSUNG',
#   'RAM': '16GB',
#   'Rating': '4.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(29% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Thomson NEO 14.1 Inch IN-P14C Intel Celeron Dual Core N4020 Processor & Window 11 Home Notebook (4 GB RAM DDR4/ 128 GB SSD/Numeric Touch Pad/Thin & Light Weight/Silver)',
#   'Price': '12,990',
#   'Processor': None,
#   'Brand': 'THOMSON',
#   'RAM': '4GB',
#   'Rating': '3.0',
#   'Storage': '128GB',
#   'Windows': 'N/A',
#   'Color': 'Silver',
#   'Discount': '(48% off)',
#   'Screen Size': 'N/A'},
#  {'Title': "HP Victus, 14th Gen Intel Core i5-14450HX, 6GB RTX 3050, 24GB DDR5, 512GB SSD, FHD, 144Hz, IPS, 300 nits, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.3kg, fa2303tx, RGB Gaming Laptop",
#   'Price': '80,490',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook S16,14th Gen, Intel Core 5-210H,Metallic Design Laptop(Intel UHD iGPU/16GB RAM/512GB SSD/FHD+/16"/144Hz/Windows 11/M365 Basic(1Year)*/Office Home 2024/Silver/1.7Kg) S3607VA-RP114WS',
#   'Price': '67,990',
#   'Processor': None,
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Metallic',
#   'Discount': '(1% off)',
#   'Screen Size': '16'},
#  {'Title': 'MSI Thin 15, Intel 13th Gen. Core i5-13420H, 40CM FHD 144Hz Gaming Laptop(16GB/512GB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 3050,GDDR6 4GB/Cosmos Gray/1.86Kg), B13UC-1805IN',
#   'Price': '60,625',
#   'Processor': 'i5',
#   'Brand': 'MSI',
#   'RAM': 'N/A',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(27% off)',
#   'Screen Size': '40'},
#  {'Title': 'Dell 15, Intel Core i5 13th Gen-1334U, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Silver, 1.62kg, [Dell 15], Backlit Keyboard, 15 Month McAfee, Thin & Light, Laptop',
#   'Price': '57,926',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.7',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(26% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook 15, Smartchoice, AMD Ryzen 7 5825U, 16GB RAM, 512GB SSD, FHD 15.6", Windows 11, Office Home 2024, Quiet Blue, 1.7Kg, M1502YA-BQ703WS, AMD Radeon iGPU, M365 Basic (1Year)*, 42Whr Laptop',
#   'Price': '48,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Blue',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP Smartchoice Victus, 13th Gen Intel Core i7-13620H, 8GB RTX 5050, 24GB DDR5(Upgradeable) 1TB SSD, 144Hz, FHD, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.29kg, fa2309TX, RGB Gaming Laptop",
#   'Price': '1,09,990',
#   'Processor': 'i7',
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '4.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(12% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop",
#   'Price': '69,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '16'},
#  {'Title': 'Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)',
#   'Price': '22,990',
#   'Processor': None,
#   'Brand': 'PRIMEBOOK',
#   'RAM': '8GB',
#   'Rating': '4.3',
#   'Storage': '8GB',
#   'Windows': 'N/A',
#   'Color': 'Gray',
#   'Discount': '(34% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Dell 15, Intel Core i5 13th Gen-1334U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop',
#   'Price': '56,990',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.7',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(21% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+',
#   'Price': '83,990',
#   'Processor': None,
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '3.8',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(23% off)',
#   'Screen Size': '14'},
#  {'Title': 'Lenovo IdeaPad Slim 3, 12th Gen Intel Core i5-12450H (16GB LPDDR5, 512GB SSD), Anti-glare, FHD 15.6"(39.6cm), Win 11, Office Home 2024, Arctic Grey, 1.62Kg, 83ER00MDIN, Thin & Light, Backlit KB Laptop',
#   'Price': '51,328',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(28% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'HP Victus, 13th Gen Intel Core i7-13620H, 8GB RTX 5060, 24GB DDR5(Upgradeable) 1TB SSD, 144Hz, 300nits, IPS, FHD, 15.6"/39.6cm, Win11, M365* Office 24, Mica Silver, 2.29Kg, fa2308TX, RGB Gaming Laptop',
#   'Price': '1,19,490',
#   'Processor': 'i7',
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '4.2',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(12% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS TUF A15, AMD Ryzen 7 7445HS, Gaming Laptop(RTX 3050-4GB/75W TGP/32GB RAM/1TB SSD/FHD/15.6"/144Hz/Backlit Keyboard/48Whrs/Windows 11/Graphite Black/2.3 Kg) FA506NCG-HN250W',
#   'Price': '82,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'ASUS',
#   'RAM': '32GB',
#   'Rating': '4.2',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Graphite',
#   'Discount': '(13% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook 15, Intel Core i7 13th Gen 13620H, 16GB RAM, 512GB SSD, FHD 15.6", Windows 11, Office Home 2024, Quiet Blue, 1.70kg, X1502VA-BQ838WS, Intel UHD iGPU, M365 Basic (1Year)* Laptop',
#   'Price': '63,990',
#   'Processor': 'i7',
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Blue',
#   'Discount': '(26% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP Smartchoice Victus, 13th Gen Intel Core i7-13620H, 8GB RTX 5050, 24GB DDR5(Upgradeable) 1TB SSD, 144Hz, FHD, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.29kg, fa2309TX, RGB Gaming Laptop",
#   'Price': '1,09,990',
#   'Processor': 'i7',
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '4.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(12% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'acer Nitro V 15, AMD Ryzen 7-7445HS, NVIDIA GeForce RTX 4050-6 GB, 16GB DDR5, 512GB SSD, FHD IPS, 15.6"/39.62cm, 165Hz, Win 11 Home, Obsidian Black, 2.1KG, ANV15-42, Gaming Laptop',
#   'Price': '76,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'ACER',
#   'RAM': '16GB',
#   'Rating': '3.8',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(29% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'DELL 14 (2026) Intel Core 3 14th Gen 100U - (16 GB DDR5/512 GB SSD/Intel UHD Graphics/Windows 11 Home) Thin and Light Business Laptop/14.0" FHD+ IPS Display/Ice Blue/1.4 kg/MSO 2021',
#   'Price': '46,390',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '5.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Blue',
#   'Discount': '(1% off)',
#   'Screen Size': '14.0'},
#  {'Title': 'Lenovo LOQ, AMD Ryzen 5 7235HS, RTX 3050-6GB, 24GB RAM, 512GB SSD, FHD, 15.6"/39.6cm, 144Hz, Windows 11, Office Home 2024, Grey, 2.4Kg, 3 Mon. Game Pass, 83JC00EFIN, Gaming Laptop',
#   'Price': '76,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': '24GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(19% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop",
#   'Price': '69,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '16'},
#  {'Title': 'Dell SmartChoice G15-5530, Intel Core i5 13th Gen-13450HX, NVIDIA RTX 3050-6GB, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, 120Hz, Windows 11, MS Office 24, Dark Shadow Grey, 2.65Kg, Gaming Laptop',
#   'Price': '77,787',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(26% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP Victus, AMD Ryzen 7 7445HS, 4GB RTX 2050, 16GB DDR5(Upgradable) 512GB SSD, FHD, 144Hz, 300 nits, IPS, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.29kg, fb3123AX, Backlit, Gaming Laptop",
#   'Price': '62,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(15% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP 15, 13th Gen Intel Core i5-1335U (16GB DDR4,512GB SSD) FHD, Anti-Glare,Micro-Edge, 15.6''/39.6cm, Win11, M365(1yr)* Office24, Silver,1.59kg, fd0467tu, Iris Xe, FHD Camera w/Shutter, Backlit Laptop",
#   'Price': '54,990',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 1TB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0015QU, Light-Weight, Next-Gen AI Laptop",
#   'Price': '70,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '14'},
#  {'Title': "HP 14, Intel Core Ultra 7 155H (24GB DDR5, 1TB SSD), Micro-Edge, Anti-Glare, FHD, 14''/35.6cm, Win11, M365* Office24, Silver, 1.4kg, ep1181TU, FHD Camera, Backlit Laptop",
#   'Price': '83,850',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '3.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(5% off)',
#   'Screen Size': '14'},
#  {'Title': "HP Omen, Intel Core Ultra 9 285H, 8GB RTX 5070, 32GB DDR5, 1TB SSD, 165Hz, 2k WUXGA, 3ms, 400 nits, 16''/40.6cm, Win11, M365* Office24, Black, 2.42kg, an0012TX, Unleashed Mode, RGB, AI Gaming Laptop",
#   'Price': '1,77,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '32GB',
#   'Rating': '4.5',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(12% off)',
#   'Screen Size': '16'},
#  {'Title': 'Lenovo Yoga Slim 7 (Smartchoice) Intel Core Ultra 9 185H 14"(35.5cm) WUXGA-OLED Laptop (32GB RAM/1TB SSD/AI PC/Windows 11/Microsoft 365 Basic + Office Home 2024/1Yr ADP Free/Grey/1.39Kg), 83CV00B3IN',
#   'Price': '1,09,990',
#   'Processor': None,
#   'Brand': 'LENOVO',
#   'RAM': '32GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(30% off)',
#   'Screen Size': '14'},
#  {'Title': 'Lenovo IdeaPad 5 2-in-1 AMD Ryzen AI 7 350 (24GB RAM/1TB SSD/14 (35.5cm)/WUXGA OLED/Windows 11/Lenovo AI Now/Copilot+PC/Office Home 2024/Digital Pen 2/Grey/1.5Kg), 83KT000LIN Convertible Laptop',
#   'Price': '99,990',
#   'Processor': None,
#   'Brand': 'LENOVO',
#   'RAM': '24GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(25% off)',
#   'Screen Size': '35.5'},
#  {'Title': "HP Smartchoice Victus, 13th Gen i7-13620H, 6GB RTX 4050, 16GB DDR4(Upgradeable) 512GB SSD, 144Hz, 300nits, FHD, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.3kg, fa2100/03/04tx, Gaming Laptop",
#   'Price': '92,990',
#   'Processor': 'i7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(8% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop',
#   'Price': '44,326',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Urban Armor Gear UAG Tactical 15-inch Slim Brief, Rugged Protective Slim Secure Laptop Tablet Carrying Bag for up to 15-inch Devices - Olive',
#   'Price': '44,499.',
#   'Processor': None,
#   'Brand': 'URBAN',
#   'RAM': 'N/A',
#   'Rating': '4.4',
#   'Storage': 'N/A',
#   'Windows': 'N/A',
#   'Color': 'N/A',
#   'Discount': '(8% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Dell 15, Intel Core i5 13th Gen-1334U, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Silver, 1.62kg, [Dell 15], Backlit Keyboard, 15 Month McAfee, Thin & Light, Laptop',
#   'Price': '57,926',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.7',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(26% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop',
#   'Price': '44,326',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Microsoft New Surface Pro (11th Edition) - Windows 11 Home Copilot + PC - 13” OLED PixelSense Touchscreen - Qualcomm Snapdragon X Elite (12 Core) - 32GB RAM - 1TB SSD - Platinum - ZID-00014',
#   'Price': '2,43,990',
#   'Processor': None,
#   'Brand': 'MICROSOFT',
#   'RAM': '32GB',
#   'Rating': '2.9',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Platinum',
#   'Discount': '(2% off)',
#   'Screen Size': 'N/A'},
#  {'Title': "HP Smartchoice Victus, 13th Gen i7-13620H, 6GB RTX 4050, 16GB DDR4(Upgradeable) 512GB SSD, 144Hz, 300nits, FHD, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.3kg, fa2100/03/04tx, Gaming Laptop",
#   'Price': '92,990',
#   'Processor': 'i7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(8% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'acer SmartChoice ALG, 13th Gen Intel Core i5-13420H, NVIDIA GeForce RTX 3050-6GB DDR6, 16GB RAM, 512GB SSD, FHD 15.6"/39.62 cm, 144Hz, Windows 11 Home, Steel Gray, 1.99 KG, AL15G-53,Gaming Laptop',
#   'Price': '62,990',
#   'Processor': 'i5',
#   'Brand': 'ACER',
#   'RAM': '6GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook Go 14, AMD Ryzen 5 7520U, 8GB RAM, 512GB SSD, FHD 14"(1920 x 1080), Windows 11, Office Home 2024, M365 Basic (1Year)*, Black, 1.38kg, E1404FA-EB2522WS, AMD Radeon iGPU Laptop',
#   'Price': '37,577',
#   'Processor': 'Ryzen 5',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '5.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(23% off)',
#   'Screen Size': '14'},
#  {'Title': 'Acer Aspire Lite, AMD Ryzen 7-7730U, 16 GB RAM, 512 GB SSD, Full HD IPS,15.6"/39.62 cm, Windows 11 Home, MS Office, Steel Gray, 1.59 KG, AL15-41, Thin and Light Laptop',
#   'Price': '46,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'ACER',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(30% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo LOQ 2024, Intel Core i5-13450HX, 13th Gen, NVIDIA RTX 4050-6GB, 16GB RAM, 512GB SSD, FHD 144Hz, 15.6"/39.6cm, Windows 11, Office Home 2024, Grey, 2.4Kg, 83DV018JIN, 1Yr ADP Free Gaming Laptop',
#   'Price': '89,990',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(22% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS TUF A16 (2025), AMD Ryzen 7 7445HS, Gaming Laptop (RTX 4050-6GB/140W TGP/16GB RAM/1TB SSD/FHD+/16"/144Hz/56Whrs/Windows 11/M365 Basic (1Year)*/Office Home 2024/Mecha Gray/2.2Kg) FA607NUG-RL189WS',
#   'Price': '89,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.2',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(22% off)',
#   'Screen Size': '16'},
#  {'Title': 'Lenovo IdeaPad Slim 1 AMD Ryzen 5 5500U 15.6" HD Thin and Light Laptop (8GB/512GB SSD/Windows 11 Home/Office Home 2024/1 Year ADP Free/Grey/1.6Kg), 82R4011MIN',
#   'Price': '38,490',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': 'N/A',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(30% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+',
#   'Price': '83,990',
#   'Processor': None,
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '3.8',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(23% off)',
#   'Screen Size': '14'},
#  {'Title': "HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop",
#   'Price': '69,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '16'},
#  {'Title': 'Lenovo V15 AMD Ryzen 7 7730U 15.6" (39.62cm) FHD 250 Nits Antiglare Thin and Light Laptop (Free MS Office) Lifetime (16GB/512GB SSD/Windows 11/Iron Grey/1.65 Kg) 1 Year Brand Warranty, 83CRA01SIN',
#   'Price': '52,999',
#   'Processor': 'Ryzen 7',
#   'Brand': 'LENOVO',
#   'RAM': 'N/A',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(35% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Gaming V16 (2025) 14th Gen,Intel Core 7 240H Gaming Laptop (RTX 4050-6GB/16GB RAM/512GB SSD/Windows 11 Home/16/144Hz/M365*/Office Home 2024, Matte Black,1.95 Kg),V3607VU-RP275WS',
#   'Price': '92,990',
#   'Processor': None,
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(18% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'HP Professional 14 (2025), Intel Core i3 13th Gen 1315U - (16 GB/512 GB SSD/Intel UHD Graphics/Windows 11 Pro) Thin and Light Business Laptop/14.0" HD Display/Turbo Silver/1.4 Kg/MSO 2021',
#   'Price': '44,800',
#   'Processor': 'i3',
#   'Brand': 'HP',
#   'RAM': 'N/A',
#   'Rating': '5.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(9% off)',
#   'Screen Size': '14.0'},
#  {'Title': 'Lenovo V14 Intel Core i5 13th Gen 14" FHD (1920x1080) Antiglare 250 Nits Thin and Light Laptop (16GB RAM/512GB SSD/Windows 11 Home/Office 2024/Iron Grey/1.43 kg), 83A0A0PTIN',
#   'Price': '53,500',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '3.8',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(29% off)',
#   'Screen Size': '14'},
#  {'Title': 'ASUS Vivobook Go 15, 7000 Series, AMD Ryzen 3 7320U, 8 GB RAM, 512GB SSD, FHD, Anti-Glare, 15.6", 39.6 cm, Windows 11 Home, M365 Basic(1yr)* Office24, Cool Silver, 1.63 kg, E1504FA-BQ2321WS, Laptop',
#   'Price': '34,990',
#   'Processor': 'Ryzen 3',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Google Pixelbook Go 128GB Multi-Touch Chromebook/Laptop (Just Black)',
#   'Price': '49,990',
#   'Processor': None,
#   'Brand': 'GOOGLE',
#   'RAM': 'N/A',
#   'Rating': '4.4',
#   'Storage': '128GB',
#   'Windows': 'N/A',
#   'Color': 'Black',
#   'Discount': '(47% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Lenovo ThinkBook 16, AMD Ryzen 7 7735HS, 16GB RAM, 512GB SSD, WUXGA IPS 16", Windows 11 Home, Office 2024, 1.7kg, 21MWA0R4IN, Backlit Keyboard, Fingerprint, 300 Nits, 1Y Warranty, Aluminium Top Laptop',
#   'Price': '59,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'N/A',
#   'Discount': '(35% off)',
#   'Screen Size': '16'},
#  {'Title': 'ASUS Vivobook Go 14, AMD Ryzen 5 7520U, 16GB RAM,512GB SSD,FHD,14,60Hz,42WHrs,Windows 11,M365 Basic (1Year)*,Office Home 2024,Mixed Black,Backlit KB,1.38 kg E1404FA-NK5542WS, Thin & Light Laptop',
#   'Price': '42,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.5',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(19% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Dell G15-5530, Intel Core i5 13th Gen -13450HX, RTX 3050-6GB, 16GB DDR5, 512GB SSD, FHD, 15.6"/39.62cm, 120Hz, Windows 11, MS Office 21, Dark Shadow Grey, 2.65KG, G15-5530, Backlit KB, Gaming Laptop',
#   'Price': '75,990',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(23% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'acer Aspire Lite, Intel Core 5 210H Processor, 16 GB RAM, 512 GB SSD, Full HD IPS, 15.6"/39.62 cm, Windows 11 Home, MSO, Pure Silver, 1.70 kgs, AL15-52H, Backlit Keyboard, Thin and Light Laptop',
#   'Price': '54,999',
#   'Processor': None,
#   'Brand': 'ACER',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(31% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Dell 15, Intel Core i5 13th Gen-1334U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop',
#   'Price': '56,990',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.7',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(21% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+',
#   'Price': '83,990',
#   'Processor': None,
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '3.8',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(23% off)',
#   'Screen Size': '14'},
#  {'Title': 'Thomson NEO 14.1 Inch IN-P14C Intel Dual Core 4020 & Window 11 Notebook (8 GB RAM DDR4/ 256 GB SSD/Numeric Touch Pad/1MP Webcam/White)',
#   'Price': '14,990',
#   'Processor': None,
#   'Brand': 'THOMSON',
#   'RAM': '8GB',
#   'Rating': 'N/A',
#   'Storage': '256GB',
#   'Windows': 'N/A',
#   'Color': 'White',
#   'Discount': '(46% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'ASUS Vivobook Go 15, 7000 Series, AMD Ryzen 3 7320U, 8 GB RAM, 512GB SSD, FHD, Anti-Glare, 15.6", 39.6 cm, Windows 11 Home, M365 Basic(1yr)* Office24, Cool Silver, 1.63 kg, E1504FA-BQ2321WS, Laptop',
#   'Price': '34,990',
#   'Processor': 'Ryzen 3',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook Go 14, AMD Ryzen 5 7520U, 16GB RAM,512GB SSD,FHD,14,60Hz,42WHrs,Windows 11,M365 Basic (1Year)*,Office Home 2024,Mixed Black,Backlit KB,1.38 kg E1404FA-NK5542WS, Thin & Light Laptop',
#   'Price': '42,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.5',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(19% off)',
#   'Screen Size': 'N/A'},
#  {'Title': "HP 15 Laptop, AMD Ryzen 7 5825U [16GB DDR4,512GB SSD] [Win11, Office Home'2024/M365 Basic(1yr)*] [Anti-Glare,Micro-Edge,15.6''/39.6cm FHD]Silver,1.59kg [Backlit KB+FHD Camera+Radeon Graphics] fc0533AU",
#   'Price': '49,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(17% off)',
#   'Screen Size': '11'},
#  {'Title': 'Dell 15, AMD Ryzen 7-7730U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.6cm, Windows 11, MSO-24, Platinum Silver, 1.63Kg, [Dell 15], 120Hz 250nits, AMD Radeon Graphics, Standard Keyboard, Thin & Light, Laptop',
#   'Price': '51,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.6',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Platinum',
#   'Discount': '(19% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Microsoft Surface Laptop Studio - 14.4 Inches Touchscreen - Intel Core I5-16Gb Memory - 256Gb Ssd - Platinum Windows 11 (Thr-00022) - Wi-Fi',
#   'Price': '1,24,990',
#   'Processor': None,
#   'Brand': 'MICROSOFT',
#   'RAM': 'N/A',
#   'Rating': '3.1',
#   'Storage': '256GB',
#   'Windows': 'Windows 11',
#   'Color': 'Platinum',
#   'Discount': '(34% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Dell SmartChoice G15-5530, Intel Core i5 13th Gen-13450HX, NVIDIA RTX 3050-6GB, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, 120Hz, Windows 11, MS Office 24, Dark Shadow Grey, 2.65Kg, Gaming Laptop',
#   'Price': '77,787',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(26% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP Laptop 15, Intel Core i5-1335U-13th Gen, (16GB DDR4,512GB SSD) Anti-Glare, Micro-Edge, FHD, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, Iris Xe, FHD Camera w/Shutter",
#   'Price': '55,990',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(22% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop",
#   'Price': '69,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '16'},
#  {'Title': 'Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop',
#   'Price': '44,326',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook 15 (2025), 13th Gen,Intel Core i3-1315U, 8GB RAM, 512GB SSD, FHD, 15.6", 39.6 cm, Windows 11 Home,M365 Basic(1 Year)* Office 2024,Cool Silver,1.7 Kg, X1504VA-D5321WS, Thin & Light Laptop',
#   'Price': '37,877',
#   'Processor': 'i3',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '5.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(26% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Thomson 15.6 Inch In-N15I Windows 11, Intel Corei3 12Th Gen 1215U (8GB DDR / 512GB SSD/Backlight Keyboard) Window 11 (Stylish, 1.65Kg, Ultra Performance/Grey Brush) Notebook',
#   'Price': '26,490',
#   'Processor': 'i3',
#   'Brand': 'THOMSON',
#   'RAM': 'N/A',
#   'Rating': '2.5',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(41% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'acer Professional 14[New Launch], 13th Gen Intel Core i7-1355U Turbo Boost, 32GB DDR4, 1TB SSD, Win11 Pro, MSO21, 14inch FHD Laptop, 3 Year Warranty, 1 Year Anti Virus, Fingerprint, Backlit KB',
#   'Price': '83,690',
#   'Processor': 'i7',
#   'Brand': 'ACER',
#   'RAM': '32GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'N/A',
#   'Discount': '(7% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'ASUS Vivobook 15, Smartchoice,Intel Corei5 13thGen 13420H, 16GB RAM, 512GB SSD, FHD 15.6", Win11, Office Home\'24, M365 Basic (1Year)*, Cool Silver, 1.70kg, X1502VA-BQ835WS, Intel UHD iGPU, Laptop',
#   'Price': '58,990',
#   'Processor': 'i5',
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo V15 G4 AMD Athlon Silver 7120U Laptop 8GB LPDDR5 Ram, 512 GB SSD PCIe, Windows 11/MS Office,15.6" FHD Screen, AMD Radeon 610M, Silver, 1 Year Brand Warranty',
#   'Price': '32,999',
#   'Processor': None,
#   'Brand': 'LENOVO',
#   'RAM': '8GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(58% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'HP Ultra 7 255H / 32 GB DDR5 RAM/ 1 TB SSD/Windows 11 Pro/5 MP IR AI Camera/ 14.0 inch AG WUXGA/Intel® Wi-Fi 7 BE201 (2x2) and Bluetooth 5.4 /Fingerprint Reader (C1KK0PT)',
#   'Price': '1,66,400',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '32GB',
#   'Rating': 'N/A',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'N/A',
#   'Discount': '(32% off)',
#   'Screen Size': 'N/A'},
#  {'Title': "HP 15 Laptop, AMD Ryzen 5 7520U (16GB DDR5,512GB SSD) Win11,M365 Basic(1yr)*Office Home24, Anti-Glare,15.6''/39.6cm,FHD,Backlit KB,FHD Camera w/Privacy Shutter,Radeon Graphics, Silver,1.59kg FC0690AU",
#   'Price': '45,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(17% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo 14 (2025), Intel Core i5 13th Gen 13420H - (16 GB/512 GB SSD/Intel UHD Graphics/Windows 11 Pro) Thin and Light Business Laptop/14.0" FHD Display/Iron Grey/1.4 kg/Microsoft Office 2021',
#   'Price': '54,300',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': 'N/A',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(22% off)',
#   'Screen Size': '14.0'},
#  {'Title': 'Urban Armor Gear UAG Tactical 15-inch Slim Brief, Rugged Protective Slim Secure Laptop Tablet Carrying Bag for up to 15-inch Devices - Olive',
#   'Price': '44,499.',
#   'Processor': None,
#   'Brand': 'URBAN',
#   'RAM': 'N/A',
#   'Rating': '4.4',
#   'Storage': 'N/A',
#   'Windows': 'N/A',
#   'Color': 'N/A',
#   'Discount': '(8% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'acer Aspire Lite, Intel Core 5 210H Processor, 16 GB RAM, 512 GB SSD, Full HD IPS, 15.6"/39.62 cm, Windows 11 Home, MSO, Pure Silver, 1.70 kgs, AL15-52H, Backlit Keyboard, Thin and Light Laptop',
#   'Price': '54,999',
#   'Processor': None,
#   'Brand': 'ACER',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(31% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Dell 15, Intel Core i5 13th Gen-1334U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop',
#   'Price': '56,990',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.7',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(21% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+',
#   'Price': '83,990',
#   'Processor': None,
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '3.8',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(23% off)',
#   'Screen Size': '14'},
#  {'Title': 'Lenovo 14 (2025), Intel Core i5 13th Gen 13420H - (16 GB/512 GB SSD/Intel UHD Graphics/Windows 11 Pro) Thin and Light Business Laptop/14.0" FHD Display/Iron Grey/1.4 kg/Microsoft Office 2021',
#   'Price': '54,300',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': 'N/A',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(22% off)',
#   'Screen Size': '14.0'},
#  {'Title': 'acer Professional 14[New Launch], 13th Gen Intel Core i7-1355U Turbo Boost, 32GB DDR4, 1TB SSD, Win11 Pro, MSO21, 14inch FHD Laptop, 3 Year Warranty, 1 Year Anti Virus, Fingerprint, Backlit KB',
#   'Price': '83,690',
#   'Processor': 'i7',
#   'Brand': 'ACER',
#   'RAM': '32GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'N/A',
#   'Discount': '(7% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop',
#   'Price': '44,326',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'acer Aspire Lite 12th Gen Intel Core i3-1215U Premium Metal Laptop (Windows 11 Home/16 GB RAM/512GB SSD) AL15-52, 39.62cm (15.6") Full HD Display, Metal Body, Steel Gray, 1.59 Kg',
#   'Price': '37,990',
#   'Processor': 'i3',
#   'Brand': 'ACER',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(28% off)',
#   'Screen Size': '62'},
#  {'Title': "HP 15, AMD Ryzen 7 5825U (16GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge,15.6''/39.6cm, Win11, M365(1yr)* Office24, Silver, 1.59kg, fc0476AU, Radeon Graphics, FHD Camera w/Shutter, Backlit Laptop",
#   'Price': '49,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(10% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo IdeaPad Slim 3 12th Gen Intel Core i5-12450H 15.6 Inch (39.6cm) FHD Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office Home 2024/3months Game Pass/Arctic Grey/1.62Kg), 83ER00MCIN',
#   'Price': '50,900',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': 'N/A',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(34% off)',
#   'Screen Size': '39.6'},
#  {'Title': 'HP 15 255R G10, AMD Ryzen 5 7535U Hexa Core (6 Core, 12 Threads, 2.9 to Max 4.3 Ghz) (8 GB/512 GB SSD/AMD Radeon Graphics/Windows 11) Thin and Light Laptop(15.6 inch HD Display, Matt Silver, 1.45 kg',
#   'Price': '38,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'HP',
#   'RAM': 'N/A',
#   'Rating': '4.5',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(13% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Microsoft New Surface Pro 12" - Windows 11 Home Copilot+ PC - LCD PixelSense Touchscreen - Qualcomm Snapdragon X Plus (8 Core) - 16GB RAM - 256GB SSD - Platinum - EP2-27654',
#   'Price': '82,526',
#   'Processor': None,
#   'Brand': 'MICROSOFT',
#   'RAM': '16GB',
#   'Rating': '3.3',
#   'Storage': '256GB',
#   'Windows': 'Windows 11',
#   'Color': 'Platinum',
#   'Discount': '(12% off)',
#   'Screen Size': '12'},
#  {'Title': "HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop",
#   'Price': '69,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '16'},
#  {'Title': 'Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop',
#   'Price': '44,326',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Microsoft Surface Laptop 5 | Laptop5-13.5� Inches- Touch Screen - Intel Core i5 12th Gen. (8GB RAM, 256GB SSD) - Windows 11 - Platinum',
#   'Price': '93,990',
#   'Processor': 'i5',
#   'Brand': 'MICROSOFT',
#   'RAM': '8GB',
#   'Rating': '4.2',
#   'Storage': '256GB',
#   'Windows': 'Windows 11',
#   'Color': 'Platinum',
#   'Discount': '(20% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Lenovo Smartchoice Ideapad Slim 3, 13th Gen Intel Core i7 13620H, 16GB RAM, 512GB SSD, WUXGA IPS, 15.3"/38.8cm, Win 11, Office 2024, Top Metal Cover Grey, 1.6Kg, 83K100CJIN/S1IN, Backlit KB, Laptop',
#   'Price': '75,990',
#   'Processor': 'i7',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(15% off)',
#   'Screen Size': '15.3'},
#  {'Title': 'Lenovo ThinkBook 16 AMD Ryzen 5 7535HS (8GB RAM/512GB SSD/Win 11 Home/Office 2024/Backlit Keyboard/Fingerprint) 16" WUXGA IPS 300 Nits Thin & Light Laptop/1Y Warranty/Aluminium Top/1.7kg, 21MWA0BRIN',
#   'Price': '48,500',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': '8GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'N/A',
#   'Discount': '(93% off)',
#   'Screen Size': '16'},
#  {'Title': 'Lenovo IdeaPad Slim 1, AMD Ryzen 5 5500U, 16GB RAM, 512GB SSD, HD, 15.6", Windows 11 Home, MS Office 21, Cloud Grey, 1.61Kg, 82R400ERIN, Integrated AMD Graphics, 1Yr ADP Free, Thin and Light Laptop',
#   'Price': '42,000',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(11% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo IdeaPad Slim 3, 13th Gen Intel Core i5 13420H, 24GB RAM, 1TB SSD, WUXGA IPS, 15.3"/38.8cm, Windows 11, Office Home 2024, Grey, 1.6Kg, Backlit Keyboard, 1Yr ADP Free, 83K100PLIN, Laptop',
#   'Price': '69,990',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': '24GB',
#   'Rating': '4.4',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(20% off)',
#   'Screen Size': '15.3'},
#  {'Title': 'Lenovo IdeaPad Flex 5 AMD Ryzen 5 5625U (16GB RAM/512GB SSD/14 (35.5cm)/WUXGA IPS/Windows 11/Office Home 2024/Lenovo Digital Pen/1Yr ADP/Grey/1.5Kg), 82XX00G4IN Convertible Laptop',
#   'Price': 'N/A',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': 'N/A',
#   'Screen Size': '35.5'},
#  {'Title': 'Lenovo ThinkBook 16, AMD Ryzen 7 7735HS, 16GB RAM, 512GB SSD, WUXGA IPS 16", Windows 11 Home, 1.7kg, 21MWA0AUIN, Backlit Keyboard, Fingerprint, 300 Nits, 1Y Warranty, Aluminium Top Laptop',
#   'Price': '57,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '3.7',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'N/A',
#   'Discount': '(38% off)',
#   'Screen Size': '16'},
#  {'Title': 'ASUS Vivobook 15,13th Gen,Intel Core i7-13620H(Intel UHD iGPU/16GB RAM/1TB SSD/FHD/15.6"/60Hz/Backlit Keyboard/42Whr/Windows 11/M365 Basic (1Year)*/Office Home 2024/Quiet Blue/1.7 Kg)X1502VA-BQ1298WS',
#   'Price': '67,990',
#   'Processor': 'i7',
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Blue',
#   'Discount': '(23% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)',
#   'Price': '22,990',
#   'Processor': None,
#   'Brand': 'PRIMEBOOK',
#   'RAM': '8GB',
#   'Rating': '4.3',
#   'Storage': '8GB',
#   'Windows': 'N/A',
#   'Color': 'Gray',
#   'Discount': '(34% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Dell 14, AMD Ryzen AI R5-340, 16GB LPDDR5X, 512GB SSD, FHD+, 14"/35.56cm, Win11, MSO 2024, Ice Blue, 1.52 Kg, [Dell 14], 300 Nits IPS, AMD Radeon Graphics, Backlit+FPS Keyboard, AI Powered Laptop',
#   'Price': '73,490',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.7',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Blue',
#   'Discount': '(16% off)',
#   'Screen Size': '14'}]

# %%
df=pd.DataFrame(data)
df
# Out:
#                                                  Title   Price Processor  \
# 0    Dell 15, Intel Core i5 13th Gen-1334U, 16GB DD...  56,990        i5
# 1    ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 3...  83,990      None
# 2    EBook 11.6" HD Laptop | Best Student & Office ...  10,990      None
# 3    JioBook 11 with Lifetime Office | Android 4G L...  10,990      None
# 4    HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4...  41,990        i3
# ..                                                 ...     ...       ...
# 127  Lenovo IdeaPad Flex 5 AMD Ryzen 5 5625U (16GB ...     N/A   Ryzen 5
# 128  Lenovo ThinkBook 16, AMD Ryzen 7 7735HS, 16GB ...  57,990   Ryzen 7
# 129  ASUS Vivobook 15,13th Gen,Intel Core i7-13620H...  67,990        i7
# 130  Primebook 2 Max 2025 (New Launch) | 8GB RAM, 2...  22,990      None
# 131  Dell 14, AMD Ryzen AI R5-340, 16GB LPDDR5X, 51...  73,490      None
#
#          Brand   RAM Rating Storage     Windows   Color   Discount Screen Size
# 0         DELL  16GB    3.7   512GB  Windows 11    Grey  (21% off)        15.6
# 1         ASUS  16GB    3.8     1TB  Windows 11    Gray  (23% off)          14
# 2        EBOOK   4GB    5.0     4GB  Windows 11   Black  (56% off)        11.6
# 3      JIOBOOK   4GB    2.9     4GB         N/A    Blue  (56% off)         N/A
# 4           HP  12GB    4.1   512GB  Windows 11  Silver  (20% off)        15.6
# ..         ...   ...    ...     ...         ...     ...        ...         ...
# 127     LENOVO  16GB    4.2   512GB  Windows 11    Grey        N/A        35.5
# 128     LENOVO  16GB    3.7   512GB  Windows 11     N/A  (38% off)          16
# 129       ASUS  16GB    4.0     1TB  Windows 11    Blue  (23% off)        15.6
# 130  PRIMEBOOK   8GB    4.3     8GB         N/A    Gray  (34% off)         N/A
# 131       DELL  16GB    3.7   512GB  Windows 11    Blue  (16% off)          14
#
# [132 rows x 11 columns]

# %%
df['Product Name'] = df['Title'].str.split(r'[|,]').str[0].str.strip()
col = df.pop('Product Name')
df.insert(0, 'Product Name', col)
df.drop("Title",axis=1,inplace=True)

# %%
df.to_csv("amazon_laptops_raw.csv")

# %%
df
# Out:
#                                           Product Name   Price Processor  \
# 0                                              Dell 15  56,990        i5
# 1                                    ASUS Vivobook S14  83,990      None
# 2                                EBook 11.6" HD Laptop  10,990      None
# 3                      JioBook 11 with Lifetime Office  10,990      None
# 4                                                HP 15  41,990        i3
# ..                                                 ...     ...       ...
# 127  Lenovo IdeaPad Flex 5 AMD Ryzen 5 5625U (16GB ...     N/A   Ryzen 5
# 128                                Lenovo ThinkBook 16  57,990   Ryzen 7
# 129                                   ASUS Vivobook 15  67,990        i7
# 130                  Primebook 2 Max 2025 (New Launch)  22,990      None
# 131                                            Dell 14  73,490      None
#
#          Brand   RAM Rating Storage     Windows   Color   Discount Screen Size
# 0         DELL  16GB    3.7   512GB  Windows 11    Grey  (21% off)        15.6
# 1         ASUS  16GB    3.8     1TB  Windows 11    Gray  (23% off)          14
# 2        EBOOK   4GB    5.0     4GB  Windows 11   Black  (56% off)        11.6
# 3      JIOBOOK   4GB    2.9     4GB         N/A    Blue  (56% off)         N/A
# 4           HP  12GB    4.1   512GB  Windows 11  Silver  (20% off)        15.6
# ..         ...   ...    ...     ...         ...     ...        ...         ...
# 127     LENOVO  16GB    4.2   512GB  Windows 11    Grey        N/A        35.5
# 128     LENOVO  16GB    3.7   512GB  Windows 11     N/A  (38% off)          16
# 129       ASUS  16GB    4.0     1TB  Windows 11    Blue  (23% off)        15.6
# 130  PRIMEBOOK   8GB    4.3     8GB         N/A    Gray  (34% off)         N/A
# 131       DELL  16GB    3.7   512GB  Windows 11    Blue  (16% off)          14
#
# [132 rows x 11 columns]
